# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import csv
import requests
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.sparse import hstack
from sklearn.preprocessing import LabelEncoder, MultiLabelBinarizer
import ast
from sklearn.neighbors import KNeighborsRegressor
import re
from collections import Counter
from wordcloud import WordCloud

# %%
df = pd.read_csv('../data/full_data/libros_completados_final.csv')
df
# Out:
# C:\Users\elena\AppData\Local\Temp\ipykernel_16316\2469390319.py:1: DtypeWarning: Columns (2,9,11,15,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/full_data/libros_completados_final.csv')
#                                             bookId  \
# 0                         2767052-the-hunger-games
# 1      2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                       2657.To_Kill_a_Mockingbird
# 3                         1885.Pride_and_Prejudice
# 4                                   41865.Twilight
# ...                                            ...
# 74784                                 SzxlzgEACAAJ
# 74785                                 Te04EQAAQBAJ
# 74786                                 s_8_EAAAQBAJ
# 74787                                 _yjnEAAAQBAJ
# 74788                                 bjZVEAAAQBAJ
#
#                                            title                 series  \
# 0                               The Hunger Games    The Hunger Games #1
# 1      Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                          To Kill a Mockingbird  To Kill a Mockingbird
# 3                            Pride and Prejudice                    NaN
# 4                                       Twilight   The Twilight Saga #1
# ...                                          ...                    ...
# 74784                     Afterimage Slow Motion                    NaN
# 74785                 When Fate Holds Its Breath                    NaN
# 74786                      Midnight Delivery Sex                    NaN
# 74787                            Monster Girl: 2                    NaN
# 74788                        La saison du soleil                    NaN
#
#                                           author  rating  \
# 0                                Suzanne Collins    4.33
# 1      J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                     Harper Lee    4.28
# 3      Jane Austen, Anna Quindlen (Introduction)    4.26
# 4                                Stephenie Meyer    3.60
# ...                                          ...     ...
# 74784                                    Jyanome     NaN
# 74785                                     Takiba     NaN
# 74786                            Neneko Narazaki     NaN
# 74787                             Kazuki Funatsu     NaN
# 74788                          Shintaro Ishihara     NaN
#
#                                              description language  \
# 0      WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  English
# 1      There is a door at the end of a silent corrido...  English
# 2      The unforgettable novel of a childhood in a sl...  English
# 3      Alternate cover edition of ISBN 9780679783268S...  English
# 4      About three things I was absolutely positive.\...  English
# ...                                                  ...      ...
# 74784                                                NaN       en
# 74785                                                NaN       de
# 74786  Mit SNS-Card zum Sammeln in der ersten Auflage...       de
# 74787  Dopo il loro incontro, Yatsuki si ritrova ad a...       it
# 74788  Lauréat du prestigieux prix Akutagawa en 1955,...       fr
#
#                 isbn                                             genres  \
# 0      9780439023481  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...
# 1      9780439358071  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 2      9780062369635  ['Classics', 'Fiction', 'Historical Fiction', ...
# 3                NaN  ['Classics', 'Fiction', 'Romance', 'Historical...
# 4      9780316015844  ['Young Adult', 'Fantasy', 'Romance', 'Vampire...
# ...              ...                                                ...
# 74784     3964335037                                         nan - yaoi
# 74785  9783551624680                     Comics & Graphic Novels - yaoi
# 74786  9783551620668                     Comics & Graphic Novels - yaoi
# 74787  9788834915899            Comics & Graphic Novels - isekai comedy
# 74788  9782714497598          Literary Collections - isekai space opera
#
#                                               characters bookFormat  pages  \
# 0      ['Katniss Everdeen', 'Peeta Mellark', 'Cato (H...  Hardcover    374
# 1      ['Sirius Black', 'Draco Malfoy', 'Ron Weasley'...  Paperback    870
# 2      ['Scout Finch', 'Atticus Finch', 'Jem Finch', ...  Paperback    324
# 3      ['Mr. Bennet', 'Mrs. Bennet', 'Jane Bennet', '...  Paperback    279
# 4      ['Edward Cullen', 'Jacob Black', 'Laurent', 'R...  Paperback    501
# ...                                                  ...        ...    ...
# 74784                                                NaN  nan - nan  224.0
# 74785                                                NaN  nan - nan   29.0
# 74786                                                NaN  nan - nan   29.0
# 74787                                                NaN  nan - nan  216.0
# 74788                                                NaN  nan - nan  131.0
#
#                               publisher publishDate firstPublishDate  \
# 0                      Scholastic Press    09/14/08              NaN
# 1                       Scholastic Inc.    09/28/04         06/21/03
# 2      Harper Perennial Modern Classics    05/23/06         07/11/60
# 3                        Modern Library    10/10/00         01/28/13
# 4             Little, Brown and Company    09/06/06         10/05/05
# ...                                 ...         ...              ...
# 74784                               NaN  2021-12-02       2021-12-02
# 74785                               NaN        2025             2025
# 74786                          Hayabusa  2021-05-04       2021-05-04
# 74787                       Edizioni BD  2020-05-01       2020-05-01
# 74788                           Belfond  2022-01-27       2022-01-27
#
#                                                   awards  numRatings  \
# 0      ['Locus Award Nominee for Best Young Adult Boo...   6376780.0
# 1      ['Bram Stoker Award for Works for Young Reader...   2507623.0
# 2      ['Pulitzer Prize for Fiction (1961)', 'Audie A...   4501075.0
# 3                                                     []   2998241.0
# 4      ['Georgia Peach Book Award (2007)', 'Buxtehude...   4964519.0
# ...                                                  ...         ...
# 74784                                                NaN         NaN
# 74785                                                NaN         NaN
# 74786                                                NaN         NaN
# 74787                                                NaN         NaN
# 74788                                                NaN         NaN
#
#        likedPercent                                            setting  \
# 0              96.0  ['District 12, Panem', 'Capitol, Panem', 'Pane...
# 1              98.0  ['Hogwarts School of Witchcraft and Wizardry (...
# 2              95.0               ['Maycomb, Alabama (United States)']
# 3              94.0  ['United Kingdom', 'Derbyshire, England (Unite...
# 4              78.0  ['Forks, Washington (United States)', 'Phoenix...
# ...             ...                                                ...
# 74784           NaN                                                NaN
# 74785           NaN                                                NaN
# 74786           NaN                                                NaN
# 74787           NaN                                                NaN
# 74788           NaN                                                NaN
#
#                                                 coverImg
# 0      https://i.gr-assets.com/images/S/compressed.ph...
# 1      https://i.gr-assets.com/images/S/compressed.ph...
# 2      https://i.gr-assets.com/images/S/compressed.ph...
# 3      https://i.gr-assets.com/images/S/compressed.ph...
# 4      https://i.gr-assets.com/images/S/compressed.ph...
# ...                                                  ...
# 74784                                                NaN
# 74785  http://books.google.com/books/content?id=6MsAE...
# 74786  http://books.google.com/books/content?id=s_8_E...
# 74787  http://books.google.com/books/content?id=_yjnE...
# 74788  http://books.google.com/books/content?id=bjZVE...
#
# [74789 rows x 20 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74789 entries, 0 to 74788
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   bookId            74789 non-null  object
#  1   title             74789 non-null  object
#  2   series            23470 non-null  object
#  3   author            74517 non-null  object
#  4   rating            53830 non-null  float64
#  5   description       71379 non-null  object
#  6   language          73542 non-null  object
#  7   isbn              74028 non-null  object
#  8   genres            74789 non-null  object
#  9   characters        52478 non-null  object
#  10  bookFormat        73316 non-null  object
#  11  pages             73162 non-null  object
#  12  publisher         66657 non-null  object
#  13  publishDate       74420 non-null  object
#  14  firstPublishDate  53463 non-null  object
#  15  awards            52478 non-null  object
#  16  numRatings        53830 non-null  float64
#  17  likedPercent      51856 non-null  float64
#  18  setting           52478 non-null  object
#  19  coverImg          71750 non-null  object
# dtypes: float64(3), object(17)
# memory usage: 11.4+ MB

# %% [markdown]
# Aplicamos sobre todo el dataframe los nulos para que los identifiqque

# %%
df.replace(
    ['NaN', 'nan', 'None', 'NULL', 'null', 'nan - nan', '', '[]', ' '], 
    np.nan, 
    inplace=True
)

# %% [markdown]
# # ISBN

# %% [markdown]
# ISBN
# Borramos la columna de isbn porque si que nos ha servido para encontrar la información de los libros pero ya no aporta nada

# %%
df = df.drop('isbn', axis=1)

# %% [markdown]
# # bookId

# %% [markdown]
# Borramos también la columna de bookId porquetampoco nos va a servir de nada

# %%
df = df.drop('bookId', axis=1)

# %% [markdown]
# # title y Author

# %% [markdown]
# título y autor
# Miramos si hay duplicados

# %%
duplicados_titulo_autor = df[
    df.duplicated(subset=['title', 'author'], keep=False)
]

# %%
n_duplicados = duplicados_titulo_autor.groupby(['title', 'author']).size()
print(n_duplicados.sort_values(ascending=False).head(20))
# Out:
# title                                                                author
# Sara Crewe; Or, What Happened at Miss Minchin's Boarding School      Burnett                                  9
# Divine Life Ring System                                              Wu Mei Ren, Da Wan                       6
# WIEDERGEBURT: Legend of the Reincarnated Warrior                     Brandon Varnell                          6
# The Ultimate Celestial Martial Emperor                               de Yun Piao Dang                         5
# The Godslaying Tower                                                 Nangong Yuan Jing                        5
# Isekai                                                               George Alfaro                            5
# Limits of Destiny                                                    Sharlyn G. Branson (Goodreads Author)    5
# My Next Life as a Villainess: All Routes Lead to Doom!               Satoru Yamaguchi                         4
# HELP! I Got Sucked Into My Boyfriend's Fantasy Dungeons Fanfiction!  Minnie Rider                             4
# Holiday Romance                                                      Charles Dickens                          4
# I'm in love with the villainess                                      Inori                                    4
# The Year's Best Dark Fantasy & Horror                                Paula Guran                              4
# Through My Window                                                    Ariana Godoy                             4
# Averno                                                               Louise Glück                             4
# Another World: Romantic Devil King                                   Xin SuiMengHan                           4
# Mexican Gothic                                                       Silvia Moreno-Garcia                     4
# The Good Person Reward System                                        Sima Tiao Liu Yi                         4
# 1984                                                                 George Orwell                            4
# Narrative Retellings                                                 Marina Lambrou                           3
# The Way of Kings                                                     Brandon Sanderson (Goodreads Author)     3
# dtype: int64

# %%
df.loc[df['author'] == 'Burnett']
# Out:
#                                                    title series   author  \
# 56619  Sara Crewe; Or, What Happened at Miss Minchin'...    NaN  Burnett
# 58713  Sara Crewe; Or, What Happened at Miss Minchin'...    NaN  Burnett
# 59191  Sara Crewe; Or, What Happened at Miss Minchin'...    NaN  Burnett
# 59192  Sara Crewe; Or, What Happened at Miss Minchin'...    NaN  Burnett
# 59195  Sara Crewe; Or, What Happened at Miss Minchin'...    NaN  Burnett
# 59196  Sara Crewe; Or, What Happened at Miss Minchin'...    NaN  Burnett
# 59197  Sara Crewe; Or, What Happened at Miss Minchin'...    NaN  Burnett
# 59198  Sara Crewe; Or, What Happened at Miss Minchin'...    NaN  Burnett
# 60511  Sara Crewe; Or, What Happened at Miss Minchin'...    NaN  Burnett
#
#        rating                                        description language  \
# 56619     NaN  Sara Crewe; Or, What Happened at Miss Minchin'...       en
# 58713     NaN  Sara Crewe; Or, What Happened at Miss Minchin'...       en
# 59191     NaN  Sara Crewe; Or, What Happened at Miss Minchin'...       en
# 59192     NaN  Sara Crewe; Or, What Happened at Miss Minchin'...       en
# 59195     NaN  Sara Crewe; Or, What Happened at Miss Minchin'...       en
# 59196     NaN  Sara Crewe; Or, What Happened at Miss Minchin'...       en
# 59197     NaN  Sara Crewe; Or, What Happened at Miss Minchin'...       en
# 59198     NaN  Sara Crewe; Or, What Happened at Miss Minchin'...       en
# 60511     NaN  Sara Crewe; Or, What Happened at Miss Minchin'...       en
#
#                               genres characters bookFormat pages  \
# 56619  nan - boarding school fiction        NaN        NaN  46.0
# 58713  nan - boarding school fiction        NaN        NaN  44.0
# 59191  nan - boarding school fiction        NaN        NaN  46.0
# 59192  nan - boarding school fiction        NaN        NaN  46.0
# 59195  nan - boarding school fiction        NaN        NaN  46.0
# 59196  nan - boarding school fiction        NaN        NaN  46.0
# 59197  nan - boarding school fiction        NaN        NaN  46.0
# 59198  nan - boarding school fiction        NaN        NaN  46.0
# 60511  nan - boarding school fiction        NaN        NaN  46.0
#
#                      publisher publishDate firstPublishDate awards  \
# 56619                      NaN  2020-11-18       2020-11-18    NaN
# 58713                      NaN  2021-05-09       2021-05-09    NaN
# 59191  Independently Published  2020-11-28       2020-11-28    NaN
# 59192  Independently Published  2020-11-20       2020-11-20    NaN
# 59195                      NaN  2020-11-17       2020-11-17    NaN
# 59196                      NaN  2020-11-15       2020-11-15    NaN
# 59197                      NaN  2021-02-10       2021-02-10    NaN
# 59198  Independently Published  2020-11-14       2020-11-14    NaN
# 60511                      NaN  2020-11-16       2020-11-16    NaN
#
#        numRatings  likedPercent setting  \
# 56619         NaN           NaN     NaN
# 58713         NaN           NaN     NaN
# 59191         NaN           NaN     NaN
# 59192         NaN           NaN     NaN
# 59195         NaN           NaN     NaN
# 59196         NaN           NaN     NaN
# 59197         NaN           NaN     NaN
# 59198         NaN           NaN     NaN
# 60511         NaN           NaN     NaN
#
#                                                 coverImg
# 56619  http://books.google.com/books/content?id=Q_QLz...
# 58713  http://books.google.com/books/content?id=Q_QLz...
# 59191  http://books.google.com/books/content?id=k8oMz...
# 59192  http://books.google.com/books/content?id=Q_QLz...
# 59195  http://books.google.com/books/content?id=Q_QLz...
# 59196  http://books.google.com/books/content?id=Q_QLz...
# 59197  http://books.google.com/books/content?id=Q_QLz...
# 59198  http://books.google.com/books/content?id=k8oMz...
# 60511  http://books.google.com/books/content?id=H2lbQ...

# %% [markdown]
# Nos quedamos con el que está en el índice 2 porque tiene más información, los demás están repetidos

# %%
df = df.loc[(df['author'] != 'Burnett') | (df.index == 2)]

# %%
df.loc[df['title'] == 'Divine Life Ring System']
# Out:
#                          title series              author  rating  \
# 66944  Divine Life Ring System    NaN  Da Wan, Wu Mei Ren     NaN
# 66945  Divine Life Ring System    NaN          Wu Mei Ren     NaN
# 66950  Divine Life Ring System    NaN  Wu Mei Ren, Da Wan     NaN
# 67378  Divine Life Ring System    NaN  Wu Mei Ren, Da Wan     NaN
# 67380  Divine Life Ring System    NaN          Wu Mei Ren     NaN
# 67596  Divine Life Ring System    NaN  Wu Mei Ren, Da Wan     NaN
# 67598  Divine Life Ring System    NaN  Wu Mei Ren, Da Wan     NaN
# 67601  Divine Life Ring System    NaN  Wu Mei Ren, Da Wan     NaN
# 67934  Divine Life Ring System    NaN  Wu Mei Ren, Da Wan     NaN
#
#                                              description language  \
# 66944  Niu Li was just an ordinary high school studen...       en
# 66945  Niu Li was just an ordinary high school studen...       en
# 66950  Niu Li was just an ordinary high school studen...       en
# 67378  Niu Li was just an ordinary high school studen...       en
# 67380  Niu Li was just an ordinary high school studen...       en
# 67596  Niu Li was just an ordinary high school studen...       en
# 67598  Niu Li was just an ordinary high school studen...       en
# 67601  Niu Li was just an ordinary high school studen...       en
# 67934  Niu Li was just an ordinary high school studen...       en
#
#                               genres characters bookFormat pages publisher  \
# 66944  Fiction - isekai high fantasy        NaN        NaN   0.0    Da WAN
# 66945  Fiction - isekai high fantasy        NaN        NaN   0.0    Da WAN
# 66950  Fiction - isekai high fantasy        NaN        NaN   0.0    Da WAN
# 67378  Fiction - isekai high fantasy        NaN        NaN   0.0    Da WAN
# 67380  Fiction - isekai high fantasy        NaN        NaN   0.0    Da WAN
# 67596  Fiction - isekai dark fantasy        NaN        NaN   0.0    Da WAN
# 67598  Fiction - isekai dark fantasy        NaN        NaN   0.0    Da WAN
# 67601  Fiction - isekai dark fantasy        NaN        NaN   0.0    Da WAN
# 67934  Fiction - isekai dark fantasy        NaN        NaN   0.0    Da WAN
#
#       publishDate firstPublishDate awards  numRatings  likedPercent setting  \
# 66944     2024-03          2024-03    NaN         NaN           NaN     NaN
# 66945     2024-03          2024-03    NaN         NaN           NaN     NaN
# 66950  2024-03-17       2024-03-17    NaN         NaN           NaN     NaN
# 67378  2024-03-17       2024-03-17    NaN         NaN           NaN     NaN
# 67380  2024-03-16       2024-03-16    NaN         NaN           NaN     NaN
# 67596  2024-03-17       2024-03-17    NaN         NaN           NaN     NaN
# 67598  2024-03-17       2024-03-17    NaN         NaN           NaN     NaN
# 67601  2024-03-17       2024-03-17    NaN         NaN           NaN     NaN
# 67934  2024-03-17       2024-03-17    NaN         NaN           NaN     NaN
#
#                                                 coverImg
# 66944  http://books.google.com/books/content?id=0XxyC...
# 66945  http://books.google.com/books/content?id=0XxyC...
# 66950  http://books.google.com/books/content?id=0XxyC...
# 67378  http://books.google.com/books/content?id=VYaRe...
# 67380  http://books.google.com/books/content?id=VYaRe...
# 67596  http://books.google.com/books/content?id=0XxyC...
# 67598  http://books.google.com/books/content?id=VYaRe...
# 67601  http://books.google.com/books/content?id=0XxyC...
# 67934  http://books.google.com/books/content?id=f7Gvs...

# %% [markdown]
# Estos están duplicados, así que nos quedamos con uno

# %%
df = df.loc[(df['title'] != 'Divine Life Ring System') | (df.duplicated(subset='title') == False)]

# %%
df.loc[df['title'] == 'WIEDERGEBURT: Legend of the Reincarnated Warrior']
# Out:
#                                                   title series  \
# 54609  WIEDERGEBURT: Legend of the Reincarnated Warrior    NaN
# 54612  WIEDERGEBURT: Legend of the Reincarnated Warrior    NaN
# 54616  WIEDERGEBURT: Legend of the Reincarnated Warrior    NaN
# 56732  WIEDERGEBURT: Legend of the Reincarnated Warrior    NaN
# 56740  WIEDERGEBURT: Legend of the Reincarnated Warrior    NaN
# 56758  WIEDERGEBURT: Legend of the Reincarnated Warrior    NaN
#
#                 author  rating  \
# 54609  Brandon Varnell     NaN
# 54612  Brandon Varnell     NaN
# 54616  Brandon Varnell     NaN
# 56732  Brandon Varnell     NaN
# 56740  Brandon Varnell     NaN
# 56758  Brandon Varnell     NaN
#
#                                              description language  \
# 54609  THE BATTLE IS WON Eryk, Kari, Fay, and Lin are...       en
# 54612  THE BATTLE IS WON Eryk travels with Herleif As...       en
# 54616  A CHANCE TO START OVER… Eryk's dreams continue...       en
# 56732  THE BATTLE IS NOT WON Eryk returns to Nevaria ...       en
# 56740  THE BATTLE IS FINALLY WON While the invading a...       en
# 56758  A CHANCE TO START OVER… At the end of his life...       en
#
#                                   genres characters bookFormat  pages  \
# 54609      Young Adult Fiction - gamelit        NaN        NaN  282.0
# 54612  Comics & Graphic Novels - gamelit        NaN        NaN  265.0
# 54616                  Fiction - gamelit        NaN        NaN  224.0
# 56732                  Fiction - gamelit        NaN        NaN  276.0
# 56740  Comics & Graphic Novels - gamelit        NaN        NaN  283.0
# 56758                  Fiction - gamelit        NaN        NaN  290.0
#
#                   publisher publishDate firstPublishDate awards  numRatings  \
# 54609  Kitsune Incorporated  2022-04-26       2022-04-26    NaN         NaN
# 54612  Kitsune Incorporated  2022-07-19       2022-07-19    NaN         NaN
# 54616  Kitsune Incorporated  2020-01-28       2020-01-28    NaN         NaN
# 56732  Kitsune Incorporated  2022-10-25       2022-10-25    NaN         NaN
# 56740  Kitsune Incorporated  2023-01-24       2023-01-24    NaN         NaN
# 56758  Kitsune Incorporated  2020-12-03       2020-12-03    NaN         NaN
#
#        likedPercent setting                                           coverImg
# 54609           NaN     NaN  http://books.google.com/books/content?id=vj_9E...
# 54612           NaN     NaN  http://books.google.com/books/content?id=vj_9E...
# 54616           NaN     NaN  http://books.google.com/books/content?id=vj_9E...
# 56732           NaN     NaN  http://books.google.com/books/content?id=vj_9E...
# 56740           NaN     NaN  http://books.google.com/books/content?id=vj_9E...
# 56758           NaN     NaN  http://books.google.com/books/content?id=vj_9E...

# %% [markdown]
# En este caso vemos que son libros diferentes de una misma saga, por eso lo que hacemos es ponerle el nombre de serie y al título ponerle número de cada serie

# %%
mask = df['title'] == 'WIEDERGEBURT: Legend of the Reincarnated Warrior'
df.loc[mask, 'series'] = 'WIEDERGEBURT: Legend of the Reincarnated Warrior'
df.loc[mask, 'title'] = [
    f"WIEDERGEBURT: Legend of the Reincarnated Warrior {i+1}" for i in range(mask.sum())
]

# %%
df.loc[df['title'] == 'The Ultimate Celestial Martial Emperor']
# Out:
#                                         title series            author  \
# 55042  The Ultimate Celestial Martial Emperor    NaN  de Yun Piao Dang
# 67770  The Ultimate Celestial Martial Emperor    NaN  de Yun Piao Dang
# 67784  The Ultimate Celestial Martial Emperor    NaN  de Yun Piao Dang
# 69260  The Ultimate Celestial Martial Emperor    NaN  de Yun Piao Dang
# 71216  The Ultimate Celestial Martial Emperor    NaN  de Yun Piao Dang
#
#        rating                                        description language  \
# 55042     NaN  Jiang Yuan, an ordinary person from Earth, fin...       en
# 67770     NaN                                                NaN       en
# 67784     NaN                                                NaN       en
# 69260     NaN  Jiang Yuan, an ordinary person from Earth, fin...       en
# 71216     NaN  Jiang Yuan, an ordinary person from Earth, fin...       en
#
#                                    genres characters bookFormat pages  \
# 55042            Fiction - isekai fantasy        NaN        NaN   0.0
# 67770          nan - isekai urban fantasy        NaN        NaN   0.0
# 67784                nan - isekai mystery        NaN        NaN   0.0
# 69260      Fiction - isekai urban fantasy        NaN        NaN   0.0
# 71216  Fiction - isekai fantasy adventure        NaN        NaN   0.0
#
#                                 publisher publishDate firstPublishDate awards  \
# 55042                        He Qiao Qiao  2024-04-12       2024-04-12    NaN
# 67770  Ultimate Celestial Martial Emperor  2024-04-12       2024-04-12    NaN
# 67784  Ultimate Celestial Martial Emperor  2024-04-12       2024-04-12    NaN
# 69260                        He Qiao Qiao  2024-03-09       2024-03-09    NaN
# 71216                        He Qiao Qiao  2024-04-12       2024-04-12    NaN
#
#        numRatings  likedPercent setting  \
# 55042         NaN           NaN     NaN
# 67770         NaN           NaN     NaN
# 67784         NaN           NaN     NaN
# 69260         NaN           NaN     NaN
# 71216         NaN           NaN     NaN
#
#                                                 coverImg
# 55042  http://books.google.com/books/content?id=KSLK0...
# 67770  http://books.google.com/books/content?id=KSLK0...
# 67784  http://books.google.com/books/content?id=KSLK0...
# 69260  http://books.google.com/books/content?id=KSLK0...
# 71216  http://books.google.com/books/content?id=KSLK0...

# %% [markdown]
# En este caso nos quedamos con uno porque están duplicados

# %%
df = df.loc[(df['title'] != 'The Ultimate Celestial Martial Emperor') | (df.duplicated(subset='title') == False)]

# %%
df.loc[df['title'] == 'The Godslaying Tower']
# Out:
#                       title series             author  rating  \
# 58267  The Godslaying Tower    NaN  Nangong Yuan Jing     NaN
# 66799  The Godslaying Tower    NaN  Nangong Yuan Jing     NaN
# 66813  The Godslaying Tower    NaN  Nangong Yuan Jing     NaN
# 68287  The Godslaying Tower    NaN  Nangong Yuan Jing     NaN
# 70585  The Godslaying Tower    NaN  Nangong Yuan Jing     NaN
#
#                                              description language  \
# 58267  Demons from beyond suddenly invaded the realm ...       en
# 66799  Demons from beyond suddenly invaded the realm ...       en
# 66813  Demons from beyond suddenly invaded the realm ...       en
# 68287  Demons from beyond suddenly invaded the realm ...       en
# 70585  Demons from beyond suddenly invaded the realm ...       en
#
#                                    genres characters bookFormat pages  \
# 58267          Fiction - isekai adventure        NaN        NaN   0.0
# 66799  Fiction - isekai fantasy adventure        NaN        NaN   0.0
# 66813          Fiction - isekai adventure        NaN        NaN   0.0
# 68287  Fiction - isekai fantasy adventure        NaN        NaN   0.0
# 70585       Fiction - isekai dark fantasy        NaN        NaN   0.0
#
#       publisher publishDate firstPublishDate awards  numRatings  likedPercent  \
# 58267  Zhou Yan  2024-04-05       2024-04-05    NaN         NaN           NaN
# 66799  Zhou Yan  2024-04-05       2024-04-05    NaN         NaN           NaN
# 66813  Zhou Yan  2024-04-05       2024-04-05    NaN         NaN           NaN
# 68287  Zhou Yan  2024-04-05       2024-04-05    NaN         NaN           NaN
# 70585  Zhou Yan  2024-04-05       2024-04-05    NaN         NaN           NaN
#
#       setting                                           coverImg
# 58267     NaN  http://books.google.com/books/content?id=sny10...
# 66799     NaN  http://books.google.com/books/content?id=sny10...
# 66813     NaN  http://books.google.com/books/content?id=sny10...
# 68287     NaN  http://books.google.com/books/content?id=sny10...
# 70585     NaN  http://books.google.com/books/content?id=sny10...

# %% [markdown]
# Nos quedamos con uno porque están duplicados

# %%
df = df.loc[(df['title'] != 'The Godslaying Tower') | (df.duplicated(subset='title') == False)]

# %%
df.loc[df['title'] == 'Isekai']
# Out:
#         title series                        author  rating  \
# 53824  Isekai    NaN  Jorge Boris, Rolando Peralta     NaN
# 53848  Isekai    NaN                 George Alfaro     NaN
# 58263  Isekai    NaN                Yenmigael 77 7     NaN
# 62999  Isekai    NaN       Gabriel Antonio Ramirez     NaN
# 65445  Isekai    NaN             M Jean-Louis VILL     NaN
# 65513  Isekai    NaN                 George Alfaro     NaN
# 65534  Isekai    NaN                 George Alfaro     NaN
# 65557  Isekai    NaN                 George Alfaro     NaN
# 66739  Isekai    NaN                 George Alfaro     NaN
# 67159  Isekai    NaN             M Jean-Louis VILL     NaN
# 68427  Isekai    NaN                Yenmigael 7 77     NaN
#
#                                              description language  \
# 53824  Isekai The Adventure is Book about adventure L...       en
# 53848  "Si tuviera el poder para cambiar al mundo... ...       es
# 58263  Immerse yourself in a captivating world of mag...       en
# 62999  What if a simple medallion didn't just transpo...       en
# 65445  Arius Lovelace is no ordinary baron. He is the...       en
# 65513  La guerra entre el Reino de Etrica y el Reino ...       es
# 65534  Luego de la tragedia personal que nuestro prot...       es
# 65557  Los años han pasado y la coronación está a la ...       es
# 66739  ¡Guerra! Las negociaciones fallaron y ahora la...       es
# 67159  Arius Lovelace is no ordinary baron. He is the...       en
# 68427  Tauchen Sie mit The Path of the Fang, dem erst...       de
#
#                                          genres characters bookFormat  pages  \
# 53824  Comics & Graphic Novels - isekai romance        NaN        NaN    0.0
# 53848                      nan - isekai romance        NaN        NaN  224.0
# 58263                Fiction - isekai adventure        NaN        NaN    0.0
# 62999      Young Adult Fiction - isekai fantasy        NaN        NaN    0.0
# 65445                   Fiction - isekai action        NaN        NaN    0.0
# 65513                      nan - isekai mystery        NaN        NaN    0.0
# 65534              nan - isekai magical realism        NaN        NaN  174.0
# 65557                    nan - isekai dystopian        NaN        NaN    0.0
# 66739                 nan - isekai dark fantasy        NaN        NaN    0.0
# 67159                   Fiction - isekai horror        NaN        NaN    0.0
# 68427                 Fiction - isekai thriller        NaN        NaN    0.0
#
#                      publisher publishDate firstPublishDate awards  \
# 53824                      NaN  2023-12-13       2023-12-13    NaN
# 53848  Independently Published  2021-05-05       2021-05-05    NaN
# 58263  Independently Published  2025-02-17       2025-02-17    NaN
# 62999  Independently Published  2025-02-09       2025-02-09    NaN
# 65445                      NaN  2024-11-26       2024-11-26    NaN
# 65513  Independently Published  2023-11-27       2023-11-27    NaN
# 65534  Independently Published  2021-09-19       2021-09-19    NaN
# 65557  Independently Published  2022-05-31       2022-05-31    NaN
# 66739  Independently Published  2023-02-05       2023-02-05    NaN
# 67159                      NaN  2024-11-26       2024-11-26    NaN
# 68427  Independently Published  2025-02-27       2025-02-27    NaN
#
#        numRatings  likedPercent setting  \
# 53824         NaN           NaN     NaN
# 53848         NaN           NaN     NaN
# 58263         NaN           NaN     NaN
# 62999         NaN           NaN     NaN
# 65445         NaN           NaN     NaN
# 65513         NaN           NaN     NaN
# 65534         NaN           NaN     NaN
# 65557         NaN           NaN     NaN
# 66739         NaN           NaN     NaN
# 67159         NaN           NaN     NaN
# 68427         NaN           NaN     NaN
#
#                                                 coverImg
# 53824  http://books.google.com/books/content?id=YCRXE...
# 53848  http://books.google.com/books/content?id=YCRXE...
# 58263  http://books.google.com/books/content?id=YCRXE...
# 62999  http://books.google.com/books/content?id=XsSoE...
# 65445  http://books.google.com/books/content?id=XsSoE...
# 65513  http://books.google.com/books/content?id=XsSoE...
# 65534  http://books.google.com/books/content?id=XsSoE...
# 65557  http://books.google.com/books/content?id=XsSoE...
# 66739  http://books.google.com/books/content?id=XsSoE...
# 67159  http://books.google.com/books/content?id=XsSoE...
# 68427  http://books.google.com/books/content?id=XsSoE...

# %% [markdown]
# A los libros de George Alfaro les añadimos un número como serie y le añadimos las serie

# %%
mask = (df['title'] == 'Isekai') & (df['author'] == 'George Alfaro')
df.loc[mask, 'series'] = 'Isekai'
df.loc[mask, 'title'] = [
    f'Isekai {i+1}' for i in range(mask.sum())
]

# %%
df.loc[df['title'] == 'Isekai']
# Out:
#         title series                        author  rating  \
# 53824  Isekai    NaN  Jorge Boris, Rolando Peralta     NaN
# 58263  Isekai    NaN                Yenmigael 77 7     NaN
# 62999  Isekai    NaN       Gabriel Antonio Ramirez     NaN
# 65445  Isekai    NaN             M Jean-Louis VILL     NaN
# 67159  Isekai    NaN             M Jean-Louis VILL     NaN
# 68427  Isekai    NaN                Yenmigael 7 77     NaN
#
#                                              description language  \
# 53824  Isekai The Adventure is Book about adventure L...       en
# 58263  Immerse yourself in a captivating world of mag...       en
# 62999  What if a simple medallion didn't just transpo...       en
# 65445  Arius Lovelace is no ordinary baron. He is the...       en
# 67159  Arius Lovelace is no ordinary baron. He is the...       en
# 68427  Tauchen Sie mit The Path of the Fang, dem erst...       de
#
#                                          genres characters bookFormat pages  \
# 53824  Comics & Graphic Novels - isekai romance        NaN        NaN   0.0
# 58263                Fiction - isekai adventure        NaN        NaN   0.0
# 62999      Young Adult Fiction - isekai fantasy        NaN        NaN   0.0
# 65445                   Fiction - isekai action        NaN        NaN   0.0
# 67159                   Fiction - isekai horror        NaN        NaN   0.0
# 68427                 Fiction - isekai thriller        NaN        NaN   0.0
#
#                      publisher publishDate firstPublishDate awards  \
# 53824                      NaN  2023-12-13       2023-12-13    NaN
# 58263  Independently Published  2025-02-17       2025-02-17    NaN
# 62999  Independently Published  2025-02-09       2025-02-09    NaN
# 65445                      NaN  2024-11-26       2024-11-26    NaN
# 67159                      NaN  2024-11-26       2024-11-26    NaN
# 68427  Independently Published  2025-02-27       2025-02-27    NaN
#
#        numRatings  likedPercent setting  \
# 53824         NaN           NaN     NaN
# 58263         NaN           NaN     NaN
# 62999         NaN           NaN     NaN
# 65445         NaN           NaN     NaN
# 67159         NaN           NaN     NaN
# 68427         NaN           NaN     NaN
#
#                                                 coverImg
# 53824  http://books.google.com/books/content?id=YCRXE...
# 58263  http://books.google.com/books/content?id=YCRXE...
# 62999  http://books.google.com/books/content?id=XsSoE...
# 65445  http://books.google.com/books/content?id=XsSoE...
# 67159  http://books.google.com/books/content?id=XsSoE...
# 68427  http://books.google.com/books/content?id=XsSoE...

# %% [markdown]
# Del autor M Jean-Louis Vill están duplicados así que nos quedamos con uno

# %%
# Filtrar los duplicados específicos
mask = (df['title'] == 'Isekai') & (df['author'] == 'M Jean-Louis VILL')
indexes_to_drop = df[mask].index[1:] 
df = df.drop(indexes_to_drop)

# %%
df[df['title'].duplicated()]
# Out:
#                                 title              series  \
# 664                           Inferno   Robert Langdon #4
# 768                     The Awakening   Darkest Powers #2
# 913                     Into the Wild         Warriors #1
# 1210                           Burned           Burned #1
# 1387                  North and South  North and South #1
# ...                               ...                 ...
# 74711     Writing Memoir (Lit Starts)                 NaN
# 74718              Turtle in Paradise                 NaN
# 74728  The Blue Poetry Book Annotated                 NaN
# 74737            In Other Words, Love                 NaN
# 74752                Lost in the Dark                 NaN
#
#                                             author  rating  \
# 664                   Dan Brown (Goodreads Author)    3.85
# 768            Kelley Armstrong (Goodreads Author)    4.14
# 913                                    Erin Hunter    4.30
# 1210              Ellen Hopkins (Goodreads Author)    4.25
# 1387                                    John Jakes    4.20
# ...                                            ...     ...
# 74711  San Francisco San Francisco Writers' Grotto     NaN
# 74718          Jennifer L. Holm, Savanna Ganucheau    4.00
# 74728                                  Andrew Lang     NaN
# 74737                                 Shirley Jump     NaN
# 74752                                Brad Weismann     NaN
#
#                                              description language  \
# 664    Harvard professor of symbology Robert Langdon ...  English
# 768    If you had met me a few weeks ago, you probabl...  English
# 913    For generations, four Clans of wild cats have ...  English
# 1210   I do know things really began to spin out of c...  English
# 1387   Part history, part novel, this book chronicles...  English
# ...                                                  ...      ...
# 74711  A fill-in book from the San Francisco Writers'...       en
# 74718  A graphic novel adaptation of the beloved, bes...       en
# 74728  The Blue Poetry Book was the third of the seri...       en
# 74737  She’s been hired to ghostwrite a CEO’s autobio...       en
# 74752  Two horror films were nominated for the Academ...       en
#
#                                                   genres  \
# 664    ['Fiction', 'Thriller', 'Mystery', 'Mystery Th...
# 768    ['Young Adult', 'Fantasy', 'Paranormal', 'Urba...
# 913    ['Fantasy', 'Animals', 'Fiction', 'Young Adult...
# 1210   ['Young Adult', 'Poetry', 'Fiction', 'Contempo...
# 1387   ['Historical Fiction', 'Fiction', 'Historical'...
# ...                                                  ...
# 74711                                       nan - memoir
# 74718                  Juvenile Fiction - graphic novels
# 74728                                       nan - poetry
# 74737                    Fiction - second chance romance
# 74752                   Performing Arts - zombies horror
#
#                                               characters bookFormat  pages  \
# 664    ['Robert Langdon', 'Sienna Brooks', 'Laurence ...  Hardcover    463
# 768    ['Chloe Saunders', 'Derek Souza', "Victoria 'T...  Hardcover    360
# 913    ['Lionheart', 'Graystripe', 'Fireheart', 'Blue...  Paperback    288
# 1210                    ['Ethan', 'Pattyn Von Stratten']  Hardcover    431
# 1387                      ['George Hazard', 'Orry Main']  Paperback    812
# ...                                                  ...        ...    ...
# 74711                                                NaN        NaN   96.0
# 74718                                                NaN        NaN    0.0
# 74728                                                NaN        NaN  541.0
# 74737                                                NaN        NaN    0.0
# 74752                                                NaN        NaN  257.0
#
#                          publisher       publishDate firstPublishDate  \
# 664                      Doubleday          05/14/13              NaN
# 768                  HarperCollins          04/28/09              NaN
# 913                   HarperTrophy  January 6th 2004         01/09/03
# 1210   Margaret K. McElderry Books    April 1st 2006         03/28/06
# 1387                        Signet     June 1st 2000         10/28/82
# ...                            ...               ...              ...
# 74711               Abrams Noterie        2020-02-11       2020-02-11
# 74718    National Geographic Books        2021-06-29       2021-06-29
# 74728                          NaN        2020-04-28       2020-04-28
# 74737          Hallmark Publishing        2020-04-21       2020-04-21
# 74752   Univ. Press of Mississippi        2021-04-22       2021-04-22
#
#                                                   awards  numRatings  \
# 664    ['Goodreads Choice Award for Mystery & Thrille...    469149.0
# 768    ["Romantic Times Reviewers' Choice Award (RT A...    107557.0
# 913                                                  NaN     75782.0
# 1210                                                 NaN     57383.0
# 1387                                                 NaN     56771.0
# ...                                                  ...         ...
# 74711                                                NaN         NaN
# 74718                                                NaN         1.0
# 74728                                                NaN         NaN
# 74737                                                NaN         NaN
# 74752                                                NaN         NaN
#
#        likedPercent                                            setting  \
# 664            91.0  ['Istanbul (Turkey)', 'Florence (Italy)', 'Ven...
# 768            95.0              ['Buffalo, New York (United States)']
# 913            95.0                        ['The Forest', 'Fourtrees']
# 1210           94.0                         ['Nevada (United States)']
# 1387           96.0                       ['United States of America']
# ...             ...                                                ...
# 74711           NaN                                                NaN
# 74718           NaN                                                NaN
# 74728           NaN                                                NaN
# 74737           NaN                                                NaN
# 74752           NaN                                                NaN
#
#                                                 coverImg
# 664    https://i.gr-assets.com/images/S/compressed.ph...
# 768    https://i.gr-assets.com/images/S/compressed.ph...
# 913    https://i.gr-assets.com/images/S/compressed.ph...
# 1210   https://i.gr-assets.com/images/S/compressed.ph...
# 1387   https://i.gr-assets.com/images/S/compressed.ph...
# ...                                                  ...
# 74711  http://books.google.com/books/content?id=MEhzE...
# 74718  http://books.google.com/books/content?id=JdoDE...
# 74728                                                NaN
# 74737  http://books.google.com/books/content?id=J1YAE...
# 74752  http://books.google.com/books/content?id=snNUD...
#
# [4496 rows x 18 columns]

# %%
df.loc[df['title'] == 'Limits of Destiny']
# Out:
#                    title                series  \
# 11841  Limits of Destiny  Limits of Destiny #1
# 12004  Limits of Destiny  Limits of Destiny #5
# 12180  Limits of Destiny  Limits of Destiny #2
# 12498  Limits of Destiny  Limits of Destiny #3
# 12781  Limits of Destiny  Limits of Destiny #4
#
#                                       author  rating  \
# 11841  Sharlyn G. Branson (Goodreads Author)    3.86
# 12004  Sharlyn G. Branson (Goodreads Author)    4.50
# 12180  Sharlyn G. Branson (Goodreads Author)    4.32
# 12498  Sharlyn G. Branson (Goodreads Author)    4.38
# 12781  Sharlyn G. Branson (Goodreads Author)    4.47
#
#                                              description language  \
# 11841  Alexia Welson is very beautiful and men do not...      NaN
# 12004  Does love have the power to overcome all obsta...  English
# 12180  The detonation of a bomb in Kraftberg’s hotel ...  English
# 12498  Back in Switzerland, Alexia is forced to face ...  English
# 12781  What are the thresholds of pain tolerance? Ale...  English
#
#                                                   genres characters  \
# 11841  ['Romance', 'Erotica', 'Contemporary', 'Contem...        NaN
# 12004                                  ['Erotica'] - nan        NaN
# 12180  ['Contemporary Romance', 'Romance', 'Adult Fic...        NaN
# 12498          ['Contemporary Romance', 'Romance'] - nan        NaN
# 12781  ['Romance', 'Contemporary Romance', 'Contempor...        NaN
#
#            bookFormat pages           publisher        publishDate  \
# 11841           ebook   NaN  Smashwords Edition   August 30th 2015
# 12004  Kindle Edition   260  Sharlyn G. Branson    March 31st 2016
# 12180  Kindle Edition   189                 NaN     July 20th 2015
# 12498  Kindle Edition   314  Sharlyn G. Branson   August 17th 2015
# 12781  Kindle Edition   179  Sharlyn G. Branson  October 15th 2015
#
#       firstPublishDate awards  numRatings  likedPercent          setting  \
# 11841         07/10/15    NaN       497.0          87.0  ['Switzerland']
# 12004              NaN    NaN       114.0          96.0              NaN
# 12180              NaN    NaN       184.0          95.0              NaN
# 12498              NaN    NaN       156.0          96.0              NaN
# 12781              NaN    NaN       150.0          96.0              NaN
#
#                                                 coverImg
# 11841  https://i.gr-assets.com/images/S/compressed.ph...
# 12004  https://i.gr-assets.com/images/S/compressed.ph...
# 12180  https://i.gr-assets.com/images/S/compressed.ph...
# 12498  https://i.gr-assets.com/images/S/compressed.ph...
# 12781  https://i.gr-assets.com/images/S/compressed.ph...

# %% [markdown]
# En este caso, lo que vamos a hacer es pasar el numero de serie al titulo

# %%
mask = df['title'] == 'Limits of Destiny'
df.loc[mask, 'title'] = df.loc[mask].apply(
    lambda row: f"{row['title']} {row['series'].split('#')[-1].strip()}" if pd.notnull(row['series']) else row['title'],
    axis=1
)
df.loc[mask, 'series'] = 'Limits of Destiny'

# %%
duplicados_titulo_autor = df[
    df.duplicated(subset=['title', 'author'], keep=False)
]
n_duplicados = duplicados_titulo_autor.groupby(['title', 'author']).size()
print(n_duplicados.sort_values(ascending=False).head(20))
# Out:
# title                                                                author
# My Next Life as a Villainess: All Routes Lead to Doom!               Satoru Yamaguchi                4
# Another World: Romantic Devil King                                   Xin SuiMengHan                  4
# Mexican Gothic                                                       Silvia Moreno-Garcia            4
# I'm in love with the villainess                                      Inori                           4
# Holiday Romance                                                      Charles Dickens                 4
# HELP! I Got Sucked Into My Boyfriend's Fantasy Dungeons Fanfiction!  Minnie Rider                    4
# The Year's Best Dark Fantasy & Horror                                Paula Guran                     4
# Through My Window                                                    Ariana Godoy                    4
# Averno                                                               Louise Glück                    4
# The Good Person Reward System                                        Sima Tiao Liu Yi                4
# 1984                                                                 George Orwell                   4
# Fandom Culture and The Archers                                       Cara Courage, Nicola Headlam    3
# Love, Power, and Gender in Seventeenth-Century French Fairy Tales    Bronwyn Reddan                  3
# CyberPunk                                                            Runtill sun                     3
# Creswell Legacy                                                      Kylie Bellerose                 3
# Crave                                                                Tracy Wolff                     3
# The Summer of '98                                                    Tay Marley                      3
# Legacy Academy                                                       M Guida                         3
# Lost in the Dark                                                     Brad Weismann                   3
# The Wall of Winnipeg and Me                                          Mariana Zapata                  3
# dtype: int64

# %% [markdown]
# Miramos cuantos titulos y autores hay vacíos

# %%
df[['author', 'title']].isna().sum()
# Out:
# author    272
# title       0
# dtype: int64

# %% [markdown]
# Borramos los autores vacíos

# %%
df = df[df['author'].notna()]

# %% [markdown]
# # Series

# %% [markdown]
# Los libros independientes que no vienen de series, los cambiamos de no nulos a Standalone Novel

# %%
df['series'].fillna("Standalone Novel", inplace=True)
df['series']
# Out:
# 0          The Hunger Games #1
# 1              Harry Potter #5
# 2        To Kill a Mockingbird
# 3             Standalone Novel
# 4         The Twilight Saga #1
#                  ...
# 74784         Standalone Novel
# 74785         Standalone Novel
# 74786         Standalone Novel
# 74787         Standalone Novel
# 74788         Standalone Novel
# Name: series, Length: 74491, dtype: object

# %% [markdown]
# # Description

# %% [markdown]
# Borramos las filas que están vacías

# %%
df['description'].isnull().sum()
# Out:
# 3240

# %%
df = df.dropna(subset=['description'])

# %% [markdown]
# Miramos los libros en los que se duplica la descripción, el títutlo y el autor

# %%
duplicados_title_description = df[df.duplicated(subset=['title', 'description', 'author'], keep='first')]
duplicados_title_description
# Out:
#                                                    title  \
# 22515  Mute: Poems That Saved My Life!: Poems by Vidy...
# 37431                                   Promises to Keep
# 37432                                              Click
# 37433                          Die Unendlichkeit schläft
# 37434                  Death Note: Black Edition, Vol. 2
# ...                                                  ...
# 74532                          The Big Book of Cyberpunk
# 74643  The Scum Villain's Self-Saving System: Ren Zha...
# 74728                     The Blue Poetry Book Annotated
# 74737                               In Other Words, Love
# 74752                                   Lost in the Dark
#
#                                 series  \
# 22515                 Standalone Novel
# 37431                 Standalone Novel
# 37432                 Standalone Novel
# 37433  Loki von Schallern Staffel 1 #3
# 37434     Death Note: Black Edition #2
# ...                                ...
# 74532                 Standalone Novel
# 74643                 Standalone Novel
# 74728                 Standalone Novel
# 74737                 Standalone Novel
# 74752                 Standalone Novel
#
#                                                   author  rating  \
# 22515                                      Vidya Gargote    5.00
# 37431                                        Ann Tatlock    3.94
# 37432  Eoin Colfer, Linda Sue Park, Ruth Ozeki (Goodr...    3.54
# 37433                                      Melanie Meier    4.50
# 37434  Tsugumi Ohba, Takeshi Obata, Yuki Kowalsky (tr...    4.48
# ...                                                  ...     ...
# 74532                                       Jared Shurin     NaN
# 74643                                  Mo Xiang Tong Xiu    4.50
# 74728                                        Andrew Lang     NaN
# 74737                                       Shirley Jump     NaN
# 74752                                      Brad Weismann     NaN
#
#                                              description language  \
# 22515  MUTE:  Poems That Saved My Life! is an inspira...       en
# 37431  Eleven-year-old Roz (Rosalind) Anthony and her...  English
# 37432  A video message from a dead person. A larcenou...  English
# 37433  Überall, wo er hingeht, reißen Höllenfeuer all...   German
# 37434  Intégrale regroupant les tomes 3 et 4Tome 3 :L...   German
# ...                                                  ...      ...
# 74532  A genre-defining—and redefining—collection of ...       en
# 74643  NEW YORK TIMES BEST SELLER! The blockbuster da...       en
# 74728  The Blue Poetry Book was the third of the seri...       en
# 74737  She’s been hired to ghostwrite a CEO’s autobio...       en
# 74752  Two horror films were nominated for the Academ...       en
#
#                                                   genres  \
# 22515                                           [] - nan
# 37431  ['Fiction', 'Christian Fiction', 'Christian', ...
# 37432  ['Young Adult', 'Fiction', 'Short Stories', 'M...
# 37433                                           [] - nan
# 37434  ['Graphic Novels', 'Comics', 'Fantasy', 'Manga...
# ...                                                  ...
# 74532                                Fiction - cyberpunk
# 74643                                   Fiction - danmei
# 74728                                       nan - poetry
# 74737                    Fiction - second chance romance
# 74752                   Performing Arts - zombies horror
#
#                      characters       bookFormat   pages  \
# 22515                       NaN        Paperback     210
# 37431                       NaN        Paperback     348
# 37432                       NaN  Unknown Binding     217
# 37433                       NaN   Kindle Edition     NaN
# 37434  ['Light Yagami', 'Ryuk']        Paperback     385
# ...                         ...              ...     ...
# 74532                       NaN              NaN  1137.0
# 74643                       NaN              NaN     0.0
# 74728                       NaN              NaN   541.0
# 74737                       NaN              NaN     0.0
# 74752                       NaN              NaN   257.0
#
#                         publisher        publishDate firstPublishDate  \
# 22515                Balboa Press  October 21st 2014              NaN
# 37431    Bethany House Publishers  February 1st 2011         01/01/11
# 37432                   Not Avail   October 1st 2007         11/06/07
# 37433    neobooks Self-Publishing      November 2014              NaN
# 37434                    Tokyopop               2009         11/06/03
# ...                           ...                ...              ...
# 74532                     Vintage         2023-09-26       2023-09-26
# 74643                  Seven Seas         2021-12-14       2021-12-14
# 74728                         NaN         2020-04-28       2020-04-28
# 74737         Hallmark Publishing         2020-04-21       2020-04-21
# 74752  Univ. Press of Mississippi         2021-04-22       2021-04-22
#
#                                                   awards  numRatings  \
# 22515                                                NaN         1.0
# 37431                                                NaN      1997.0
# 37432  ['Deutscher Jugendliteraturpreis Nominee for J...      1910.0
# 37433                                                NaN         2.0
# 37434                                                NaN      5849.0
# ...                                                  ...         ...
# 74532                                                NaN         NaN
# 74643                                                NaN         2.0
# 74728                                                NaN         NaN
# 74737                                                NaN         NaN
# 74752                                                NaN         NaN
#
#        likedPercent                       setting  \
# 22515         100.0                           NaN
# 37431          95.0  ['Illinois (United States)']
# 37432          86.0                           NaN
# 37433           NaN                           NaN
# 37434          99.0                           NaN
# ...             ...                           ...
# 74532           NaN                           NaN
# 74643           NaN                           NaN
# 74728           NaN                           NaN
# 74737           NaN                           NaN
# 74752           NaN                           NaN
#
#                                                 coverImg
# 22515  http://books.google.com/books/content?id=zgRUB...
# 37431  https://i.gr-assets.com/images/S/compressed.ph...
# 37432  https://i.gr-assets.com/images/S/compressed.ph...
# 37433  https://i.gr-assets.com/images/S/compressed.ph...
# 37434  https://i.gr-assets.com/images/S/compressed.ph...
# ...                                                  ...
# 74532  http://books.google.com/books/content?id=R2y1E...
# 74643  http://books.google.com/books/content?id=PqVKE...
# 74728                                                NaN
# 74737  http://books.google.com/books/content?id=J1YAE...
# 74752  http://books.google.com/books/content?id=snNUD...
#
# [349 rows x 18 columns]

# %%
df = df.drop_duplicates(subset=['title', 'description', 'author'], keep='first')

# %%
duplicados_title_description = df[df.duplicated(subset=['title', 'description'], keep='first')]
duplicados_title_description
# Out:
#                                                    title            series  \
# 20619          Cupping Therapy Encyclopedia: New Edition  Standalone Novel
# 28025            Out of the Picture and Into the Picture  Standalone Novel
# 31028  Lucid Exposition of the Middle Way: The Essent...  Standalone Novel
# 52491                                          CyberPunk  Standalone Novel
# 54934                  Love Story of an Introvert Medico  Standalone Novel
# 56533                               Todos Somos Villanos  Standalone Novel
# 58178          Oh, Great! I was Reincarnated as a Farmer  Standalone Novel
# 59520                                  Superhero Fiction  Standalone Novel
# 60360                                          Neo Magic  Standalone Novel
# 60670                                          CyberPunk  Standalone Novel
# 62682                               The Portal Guardians  Standalone Novel
# 63138                 Antiheroines of Contemporary Media  Standalone Novel
# 66307                                        Iarraindorn  Standalone Novel
# 66784                         Multi-Mind Mayhem Volume 7  Standalone Novel
# 67026                             The Archer & The Flame  Standalone Novel
# 67162        The Wrong Way to Use Healing Magic Volume 1  Standalone Novel
# 67599                            The Death Mage Volume 4  Standalone Novel
# 67802                         Multi-Mind Mayhem Volume 3  Standalone Novel
# 68911    Mythical Mermaids - Fantasy Adult Coloring Book  Standalone Novel
# 68914  Creative Haven Magnificent Mermaids Coloring Book  Standalone Novel
# 69009  Creative Haven Magnificent Mermaids Coloring Book  Standalone Novel
# 69013  Creative Haven Magnificent Mermaids Coloring Book  Standalone Novel
# 69131                         Multi-Mind Mayhem Volume 4  Standalone Novel
# 69242                   Mermaid Coloring Book for Adults  Standalone Novel
# 69384                      Zombie Coloring Book for Kids  Standalone Novel
# 69386                      Zombie Coloring Book for Kids  Standalone Novel
# 69387                      Zombie Coloring Book for Kids  Standalone Novel
# 69388                      Zombie Coloring Book for Kids  Standalone Novel
# 69389                      Zombie Coloring Book for Kids  Standalone Novel
# 69391                      Zombie Coloring Book for Kids  Standalone Novel
# 69595                  Halloween Colouring Book for Kids  Standalone Novel
# 69596                   Hallowen Colouring Book for Kids  Standalone Novel
# 69711                   Hallowen Colouring Book for Kids  Standalone Novel
# 71179  Modes of Composition and the Durability of Sty...  Standalone Novel
# 71568                      Zombie Coloring Book for Kids  Standalone Novel
# 71849                                Martial Peak Vol 48  Standalone Novel
# 71853                  Battle Through the Heavens Vol 45  Standalone Novel
# 72128             Terror Empire Coloring Book For Adults  Standalone Novel
# 72135                   Hallowen Colouring Book for Kids  Standalone Novel
# 72399                                     Fury of Angels  Standalone Novel
# 72478                  Battle Through the Heavens Vol 14  Standalone Novel
# 72758                  Battle Through the Heavens Vol 11  Standalone Novel
# 72759                                Martial Peak Vol 27  Standalone Novel
# 72760                                Martial Peak Vol 27  Standalone Novel
# 72763                  Battle Through the Heavens Vol 39  Standalone Novel
# 72766                  Battle Through the Heavens Vol 17  Standalone Novel
# 72770                  Battle Through the Heavens Vol 15  Standalone Novel
# 72772                  Battle Through the Heavens Vol 36  Standalone Novel
# 72776    Rebirth of the Urban Immortal Cultivator Vol 10  Standalone Novel
# 72777    Rebirth of the Urban Immortal Cultivator Vol 13  Standalone Novel
# 73523                  Star Martial God Technique Chap 4  Standalone Novel
# 73538                        Tang Yin's Adventure Vol 24  Standalone Novel
# 73546                         Tang Yin's Adventure Vol 7  Standalone Novel
# 73554                        Tang Yin's Adventure Vol 30  Standalone Novel
# 73560                   Tables of Demons and God Chap 45  Standalone Novel
# 73678                     Sexy Anime Girls Coloring Book  Standalone Novel
# 73683                      Sexy Anime Milf Coloring Book  Standalone Novel
# 73684                     Sexy Anime Girls Coloring Book  Standalone Novel
# 74344                          Journey To Find The Truth  Standalone Novel
#
#                                                   author  rating  \
# 20619                    Tamer Shaban (Goodreads Author)     5.0
# 28025  Victor G. La Van Way (Illustrator), Ilyan Kei ...     4.0
# 31028                                      Mervyn Sprung     0.0
# 52491                                    Cyberpunk House     NaN
# 54934                               Dr. Vaibhav Motghare     5.0
# 56533                                          M. L. Rio     NaN
# 58178                             Benjamin Neihana Kerei     5.0
# 59520                                        Terry Dolin     NaN
# 60360             Francisco Villalón López, Sam H Sharpe     NaN
# 60670                                        Runtill sun     NaN
# 62682                                      Ellie Holland     NaN
# 63138    Melanie Haas, N. A. Pierce, Gretchen Lynne Busl     NaN
# 66307                                     Philip Dickens     NaN
# 66784                      Ryousen Takami, Honoji Honoji     NaN
# 67026                                      MARIE. VIOLET     NaN
# 67162                   Kugayama Reki, Kurokata Kurokata     NaN
# 67599                                            Densuke     NaN
# 67802                Ryousen Takami, Honoji, Matt Schley     NaN
# 68911                                         Terry Pino     NaN
# 68914                                       Mermaid Jack     NaN
# 69009                                      Mermaids Momo     NaN
# 69013                                   Mermaids Margret     NaN
# 69131                      Ryousen Takami, Honoji Honoji     NaN
# 69242                                               Rfza     NaN
# 69384                                        Zombie Book     NaN
# 69386                                      Coloring Book     NaN
# 69387                                        Coloer Book     NaN
# 69388                                      Coloring Page     NaN
# 69389                                         Color Book     NaN
# 69391                                     Colouring Book     NaN
# 69595                                     Colouring Book     NaN
# 69596                                     Coloring Booke     NaN
# 69711                                        Coloer Book     NaN
# 71179                                    David L. Hoover     NaN
# 71568                                    Zombie Coloring     NaN
# 71849                                          Ryan AIKA     NaN
# 71853                                       Patel KINJAL     NaN
# 72128                                 Sweet Lemon Art Co     NaN
# 72135                                      Coloring Book     NaN
# 72399                                        Julie Light     NaN
# 72478                                       Patel KINJAL     NaN
# 72758                                       Patel KINJAL     NaN
# 72759                                       Jamie Fields     NaN
# 72760                                      James FREEMAN     NaN
# 72763                                       Patel KINJAL     NaN
# 72766                                   reuben nisenfeld     NaN
# 72770                                  Richard CONTRERAS     NaN
# 72772                                       Patel KINJAL     NaN
# 72776                                        Dawood HALA     NaN
# 72777                                    Lonny DAUGHERTY     NaN
# 73523                                    VEGA-RIVERA LUZ     NaN
# 73538                                   Ortiz Vega MARIA     NaN
# 73546                                   reuben nisenfeld     NaN
# 73554                                   reuben nisenfeld     NaN
# 73560                                        Noah Nguyen     NaN
# 73678                                  World Of Coloring     NaN
# 73683                              Activity Coloring Art     NaN
# 73684                                          Funny Art     NaN
# 74344                                    Delmar Coldwell     NaN
#
#                                              description language  \
# 20619  This book describes the history, methods, and ...      NaN
# 28025  Out of the Picture and Into the Picture by Vic...  English
# 31028  Originally published in 1979.The Prasannapada ...       en
# 52491  Attention Cyberpunk Army, Looking for a new Ga...       en
# 54934  Every person on this planet, whether introvert...       en
# 56533  Oliver Marks is released from jail after ten y...       es
# 58178  What do you have when you blend a pinch of lit...       en
# 59520  Superhero fiction is a genre of speculative fi...       en
# 60360  En Neo Magic encontrarás indagaciones sobre la...       es
# 60670  Attention Cyberpunk Army, Looking for a new Ga...       en
# 62682  In a magical library? ?a young elf studies. Br...       en
# 63138  This volume of essays provides a critical fora...       en
# 66307  ON THE NIGHT THAT HE WAS BORN, THE DEVIL CAME ...       en
# 66784  On the orders of King Welkin, Bard has become ...       en
# 67026  When duty meets desire, which will prevail? Wi...       en
# 67162  Usato, an ordinary high schooler, happens to r...       en
# 67599  The fight with the vampires draws near! Having...       en
# 67802  Bard Cornelius is no ordinary nobleman's son. ...       en
# 68911  A Beautiful Premium cover design, Perfect for ...       en
# 68914  Sherri Baldy's NEW SUPER Beautiful & Enchantin...       en
# 69009  Sherri Baldy's NEW SUPER Beautiful & Enchantin...       en
# 69013  Sherri Baldy's NEW SUPER Beautiful & Enchantin...       en
# 69131  Bard Cornelius is no ordinary nobleman's son. ...       en
# 69242  Dive into an underwater adventure in this beau...       en
# 69384  Unique, Cool, and Fun!8.5"x11" Glossy Cover Pa...       en
# 69386  Unique, Cool, and Fun!8.5"x11" Glossy Cover Pa...       en
# 69387  Unique, Cool, and Fun!8.5"x11" Glossy Cover Pa...       en
# 69388  Unique, Cool, and Fun!8.5"x11" Glossy Cover Pa...       en
# 69389  Unique, Cool, and Fun!8.5"x11" Glossy Cover Pa...       en
# 69391  Unique, Cool, and Fun!8.5"x11" Glossy Cover Pa...       en
# 69595  Unique, Cool, and Fun!8.5"x11" Glossy Cover Pa...       en
# 69596  Unique, Cool, and Fun!8.5"x11" Glossy Cover Pa...       en
# 69711  Unique, Cool, and Fun!8.5"x11" Glossy Cover Pa...       en
# 71179  Modes of Composition and the Durability of Sty...       en
# 71568  Unique, Cool, and Fun!8.5"x11" Glossy Cover Pa...       en
# 71849  The journey to the martial peak is a lonely, s...       en
# 71853  In a land where there is no magic, a land wher...       en
# 72128  BOO! Our Horror coloring book takes you on an ...       en
# 72135  Unique, Cool, and Fun!8.5"x11" Glossy Cover Pa...       en
# 72399  My oldest friend might just be Lucifer, Angel ...       en
# 72478  In a land where there is no magic, a land wher...       en
# 72758  In a land where there is no magic, a land wher...       en
# 72759  The journey to the martial peak is a lonely, s...       en
# 72760  The journey to the martial peak is a lonely, s...       en
# 72763  In a land where there is no magic, a land wher...       en
# 72766  In a land where there is no magic, a land wher...       en
# 72770  In a land where there is no magic, a land wher...       en
# 72772  In a land where there is no magic, a land wher...       en
# 72776  During the anti-cataclysm period, the monk Che...       en
# 72777  During the anti-cataclysm period, the monk Che...       en
# 73523  Killed by a Sage Emperor and reborn as his 13 ...       en
# 73538  "Tang Yin's Adventure in Another World" mainly...       en
# 73546  "Tang Yin's Adventure in Another World" mainly...       en
# 73554  "Tang Yin's Adventure in Another World" mainly...       en
# 73560  Killed by a Sage Emperor and reborn as his 13 ...       en
# 73678  Do you love Anime? If your answer is yes, Let'...       en
# 73683  Do you love Anime? If your answer is yes, Let'...       en
# 73684  Do you love Anime? If your answer is yes, Let'...       en
# 74344  When Ray is asked to investigate Crow's Cottag...       en
#
#                                                 genres characters  \
# 20619                                         [] - nan        NaN
# 28025                                         [] - nan        NaN
# 31028                                         [] - nan        NaN
# 52491                                  nan - cyberpunk        NaN
# 54934                      Fiction - introvert romance        NaN
# 56533                                 Fiction - romcom        NaN
# 58178                                     nan - litRPG        NaN
# 59520                          nan - superhero fiction        NaN
# 60360                          nan - magical creatures        NaN
# 60670                                  nan - cyberpunk        NaN
# 62682                             nan - portal fantasy        NaN
# 63138                  Literary Criticism - antiheroes        NaN
# 66307               nan - historical fantasy adventure        NaN
# 66784      Comics & Graphic Novels - isekai historical        NaN
# 67026                            Fiction - fae fantasy        NaN
# 67162  Comics & Graphic Novels - isekai fantasy comedy        NaN
# 67599                        nan - isekai dark fantasy        NaN
# 67802      Comics & Graphic Novels - isekai historical        NaN
# 68911                           nan - mermaids fantasy        NaN
# 68914                           nan - mermaids fantasy        NaN
# 69009                           nan - mermaids fantasy        NaN
# 69013                           nan - mermaids fantasy        NaN
# 69131           Comics & Graphic Novels - isekai drama        NaN
# 69242            Games & Activities - mermaids fantasy        NaN
# 69384                            nan - zombies fantasy        NaN
# 69386                            nan - zombies fantasy        NaN
# 69387                            nan - zombies fantasy        NaN
# 69388                            nan - zombies fantasy        NaN
# 69389                            nan - zombies fantasy        NaN
# 69391                            nan - zombies fantasy        NaN
# 69595                            nan - zombies fantasy        NaN
# 69596                            nan - zombies fantasy        NaN
# 69711                            nan - zombies fantasy        NaN
# 71179     Literary Criticism - literary fiction horror        NaN
# 71568                             nan - zombies horror        NaN
# 71849                            nan - shounen romance        NaN
# 71853                            nan - shounen romance        NaN
# 72128                             nan - zombies horror        NaN
# 72135                             nan - zombies horror        NaN
# 72399                      nan - fallen angels fantasy        NaN
# 72478                            nan - shounen romance        NaN
# 72758                            nan - shounen romance        NaN
# 72759                            nan - shounen romance        NaN
# 72760                            nan - shounen romance        NaN
# 72763                            nan - shounen romance        NaN
# 72766                            nan - shounen romance        NaN
# 72770                            nan - shounen romance        NaN
# 72772                            nan - shounen romance        NaN
# 72776                            nan - shounen romance        NaN
# 72777                            nan - shounen romance        NaN
# 73523                            nan - shounen romance        NaN
# 73538                            nan - shounen romance        NaN
# 73546                            nan - shounen romance        NaN
# 73554                            nan - shounen romance        NaN
# 73560                            nan - shounen romance        NaN
# 73678                               nan - yuri fantasy        NaN
# 73683                               nan - yuri fantasy        NaN
# 73684                               nan - yuri fantasy        NaN
# 74344                            nan - occult thriller        NaN
#
#            bookFormat  pages                  publisher      publishDate  \
# 20619  Kindle Edition    NaN                        NaN  March 24th 2018
# 28025           ebook     25         Ilyan Kei Lavanway     May 7th 2012
# 31028           ebook    302                  Routledge    May 13th 2013
# 52491             NaN  120.0                        NaN       2020-03-27
# 54934             NaN   46.0               Notion Press       2021-07-11
# 56533             NaN    0.0            Ediciones Urano       2023-06-27
# 58178             NaN  618.0                        NaN       2021-06-08
# 59520             NaN  396.0    Independently Published       2021-06-11
# 60360             NaN  160.0                        NaN       2020-03-20
# 60670             NaN  120.0                        NaN       2020-03-15
# 62682             NaN  414.0         Amalgam Chronicles       2021-12-30
# 63138             NaN    0.0                        NaN             2021
# 66307             NaN  212.0                        NaN       2021-05-31
# 66784             NaN  208.0           SCB Distributors       2023-04-11
# 67026             NaN    0.0                        NaN       2024-10-30
# 67162             NaN  198.0           SCB Distributors       2022-11-22
# 67599             NaN    0.0            One Peace Books       2024-02-13
# 67802             NaN  200.0            One Peace Books       2022-04-12
# 68911             NaN   24.0                        NaN       2020-07-10
# 68914             NaN   58.0    Independently Published       2020-08-29
# 69009             NaN   58.0    Independently Published       2020-08-29
# 69013             NaN   58.0    Independently Published       2020-08-29
# 69131             NaN  192.0           SCB Distributors       2022-07-26
# 69242             NaN  122.0  Only1million Incorporated       2020-12-03
# 69384             NaN  112.0                        NaN       2020-10-17
# 69386             NaN  112.0                        NaN       2020-10-17
# 69387             NaN  112.0                        NaN       2020-10-17
# 69388             NaN  112.0    Independently Published       2020-10-17
# 69389             NaN  112.0                        NaN       2020-10-17
# 69391             NaN  112.0                        NaN       2020-10-17
# 69595             NaN  112.0    Independently Published       2020-10-16
# 69596             NaN  112.0                        NaN       2020-10-16
# 69711             NaN  112.0                        NaN       2020-10-16
# 71179             NaN  239.0                  Routledge       2020-11-29
# 71568             NaN  112.0                        NaN       2020-10-17
# 71849             NaN   96.0                        NaN       2020-11-06
# 71853             NaN   83.0                        NaN       2020-10-19
# 72128             NaN   66.0                        NaN       2020-12-15
# 72135             NaN  112.0                        NaN       2020-10-16
# 72399             NaN  310.0                        NaN       2020-11-13
# 72478             NaN   86.0                        NaN       2020-10-19
# 72758             NaN   90.0                        NaN       2020-10-19
# 72759             NaN   71.0                        NaN       2020-09-10
# 72760             NaN   71.0                        NaN       2020-08-28
# 72763             NaN   82.0                        NaN       2020-10-19
# 72766             NaN   85.0                        NaN       2020-09-19
# 72770             NaN   83.0                        NaN          2020-09
# 72772             NaN   81.0                        NaN       2020-10-19
# 72776             NaN   75.0                        NaN       2020-10-07
# 72777             NaN   70.0                        NaN       2020-08-31
# 73523             NaN   77.0                        NaN       2020-09-28
# 73538             NaN   90.0                        NaN       2020-10-17
# 73546             NaN   73.0                        NaN       2020-09-18
# 73554             NaN   73.0                        NaN       2020-09-18
# 73560             NaN   78.0                        NaN       2020-04-03
# 73678             NaN   72.0                        NaN       2020-11-04
# 73683             NaN   81.0                        NaN       2021-06-06
# 73684             NaN   70.0                        NaN       2021-09-05
# 74344             NaN  232.0                        NaN       2021-01-12
#
#       firstPublishDate awards  numRatings  likedPercent setting  \
# 20619              NaN    NaN         3.0         100.0     NaN
# 28025              NaN    NaN         4.0          75.0     NaN
# 31028         01/01/13    NaN         0.0           NaN     NaN
# 52491       2020-03-27    NaN         NaN           NaN     NaN
# 54934       2021-07-11    NaN         4.0           NaN     NaN
# 56533       2023-06-27    NaN         NaN           NaN     NaN
# 58178       2021-06-08    NaN         1.0           NaN     NaN
# 59520       2021-06-11    NaN         NaN           NaN     NaN
# 60360       2020-03-20    NaN         NaN           NaN     NaN
# 60670       2020-03-15    NaN         NaN           NaN     NaN
# 62682       2021-12-30    NaN         NaN           NaN     NaN
# 63138             2021    NaN         NaN           NaN     NaN
# 66307       2021-05-31    NaN         NaN           NaN     NaN
# 66784       2023-04-11    NaN         NaN           NaN     NaN
# 67026       2024-10-30    NaN         NaN           NaN     NaN
# 67162       2022-11-22    NaN         NaN           NaN     NaN
# 67599       2024-02-13    NaN         NaN           NaN     NaN
# 67802       2022-04-12    NaN         NaN           NaN     NaN
# 68911       2020-07-10    NaN         NaN           NaN     NaN
# 68914       2020-08-29    NaN         NaN           NaN     NaN
# 69009       2020-08-29    NaN         NaN           NaN     NaN
# 69013       2020-08-29    NaN         NaN           NaN     NaN
# 69131       2022-07-26    NaN         NaN           NaN     NaN
# 69242       2020-12-03    NaN         NaN           NaN     NaN
# 69384       2020-10-17    NaN         NaN           NaN     NaN
# 69386       2020-10-17    NaN         NaN           NaN     NaN
# 69387       2020-10-17    NaN         NaN           NaN     NaN
# 69388       2020-10-17    NaN         NaN           NaN     NaN
# 69389       2020-10-17    NaN         NaN           NaN     NaN
# 69391       2020-10-17    NaN         NaN           NaN     NaN
# 69595       2020-10-16    NaN         NaN           NaN     NaN
# 69596       2020-10-16    NaN         NaN           NaN     NaN
# 69711       2020-10-16    NaN         NaN           NaN     NaN
# 71179       2020-11-29    NaN         NaN           NaN     NaN
# 71568       2020-10-17    NaN         NaN           NaN     NaN
# 71849       2020-11-06    NaN         NaN           NaN     NaN
# 71853       2020-10-19    NaN         NaN           NaN     NaN
# 72128       2020-12-15    NaN         NaN           NaN     NaN
# 72135       2020-10-16    NaN         NaN           NaN     NaN
# 72399       2020-11-13    NaN         NaN           NaN     NaN
# 72478       2020-10-19    NaN         NaN           NaN     NaN
# 72758       2020-10-19    NaN         NaN           NaN     NaN
# 72759       2020-09-10    NaN         NaN           NaN     NaN
# 72760       2020-08-28    NaN         NaN           NaN     NaN
# 72763       2020-10-19    NaN         NaN           NaN     NaN
# 72766       2020-09-19    NaN         NaN           NaN     NaN
# 72770          2020-09    NaN         NaN           NaN     NaN
# 72772       2020-10-19    NaN         NaN           NaN     NaN
# 72776       2020-10-07    NaN         NaN           NaN     NaN
# 72777       2020-08-31    NaN         NaN           NaN     NaN
# 73523       2020-09-28    NaN         NaN           NaN     NaN
# 73538       2020-10-17    NaN         NaN           NaN     NaN
# 73546       2020-09-18    NaN         NaN           NaN     NaN
# 73554       2020-09-18    NaN         NaN           NaN     NaN
# 73560       2020-04-03    NaN         NaN           NaN     NaN
# 73678       2020-11-04    NaN         NaN           NaN     NaN
# 73683       2021-06-06    NaN         NaN           NaN     NaN
# 73684       2021-09-05    NaN         NaN           NaN     NaN
# 74344       2021-01-12    NaN         NaN           NaN     NaN
#
#                                                 coverImg
# 20619  https://i.gr-assets.com/images/S/compressed.ph...
# 28025  https://i.gr-assets.com/images/S/compressed.ph...
# 31028  https://i.gr-assets.com/images/S/compressed.ph...
# 52491  http://books.google.com/books/content?id=iJDhE...
# 54934  http://books.google.com/books/content?id=TMk3E...
# 56533  http://books.google.com/books/content?id=v5vQE...
# 58178  http://books.google.com/books/content?id=SFSBz...
# 59520  http://books.google.com/books/content?id=Qfvtz...
# 60360  http://books.google.com/books/content?id=85Jkz...
# 60670  http://books.google.com/books/content?id=iJDhE...
# 62682  http://books.google.com/books/content?id=jM-JC...
# 63138  http://books.google.com/books/content?id=xJ9iE...
# 66307  http://books.google.com/books/content?id=8M53z...
# 66784  http://books.google.com/books/content?id=lcNYz...
# 67026  http://books.google.com/books/content?id=nusCE...
# 67162  http://books.google.com/books/content?id=DauJE...
# 67599  http://books.google.com/books/content?id=ikDtE...
# 67802  http://books.google.com/books/content?id=NZ-az...
# 68911  http://books.google.com/books/content?id=wP3aj...
# 68914  http://books.google.com/books/content?id=HzKND...
# 69009  http://books.google.com/books/content?id=HzKND...
# 69013  http://books.google.com/books/content?id=HzKND...
# 69131  http://books.google.com/books/content?id=-nKaz...
# 69242                                                NaN
# 69384  http://books.google.com/books/content?id=Mit2z...
# 69386  http://books.google.com/books/content?id=Mit2z...
# 69387  http://books.google.com/books/content?id=Mit2z...
# 69388  http://books.google.com/books/content?id=Mit2z...
# 69389  http://books.google.com/books/content?id=Mit2z...
# 69391  http://books.google.com/books/content?id=Mit2z...
# 69595  http://books.google.com/books/content?id=qjkct...
# 69596  http://books.google.com/books/content?id=p3H6z...
# 69711  http://books.google.com/books/content?id=p3H6z...
# 71179  http://books.google.com/books/content?id=eJb-D...
# 71568  http://books.google.com/books/content?id=Mit2z...
# 71849                                                NaN
# 71853                                                NaN
# 72128  http://books.google.com/books/content?id=94RJz...
# 72135  http://books.google.com/books/content?id=p3H6z...
# 72399  http://books.google.com/books/content?id=hKhQB...
# 72478                                                NaN
# 72758  http://books.google.com/books/content?id=T0LSE...
# 72759                                                NaN
# 72760                                                NaN
# 72763                                                NaN
# 72766                                                NaN
# 72770                                                NaN
# 72772                                                NaN
# 72776                                                NaN
# 72777                                                NaN
# 73523                                                NaN
# 73538                                                NaN
# 73546                                                NaN
# 73554                                                NaN
# 73560  http://books.google.com/books/content?id=t1mVz...
# 73678                                                NaN
# 73683  http://books.google.com/books/content?id=YsfAz...
# 73684                                                NaN
# 74344  http://books.google.com/books/content?id=EvVmB...

# %%
df = df.drop_duplicates(subset=['title', 'description'], keep='first')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70843 entries, 0 to 74788
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             70843 non-null  object
#  1   series            70843 non-null  object
#  2   author            70843 non-null  object
#  3   rating            52710 non-null  float64
#  4   description       70843 non-null  object
#  5   language          69706 non-null  object
#  6   genres            70843 non-null  object
#  7   characters        13733 non-null  object
#  8   bookFormat        50291 non-null  object
#  9   pages             69561 non-null  object
#  10  publisher         65346 non-null  object
#  11  publishDate       70558 non-null  object
#  12  firstPublishDate  50104 non-null  object
#  13  awards            10589 non-null  object
#  14  numRatings        52710 non-null  float64
#  15  likedPercent      51018 non-null  float64
#  16  setting           11533 non-null  object
#  17  coverImg          68762 non-null  object
# dtypes: float64(3), object(15)
# memory usage: 10.3+ MB

# %% [markdown]
# # language

# %%
df['language'].unique()
# Out:
# array(['English', 'French', 'German', 'Persian', 'Arabic', nan, 'en',
#        'Spanish', 'Multiple languages', 'Portuguese', 'Indonesian',
#        'Turkish', 'Polish', 'Bulgarian', 'Tamil', 'Japanese', 'Romanian',
#        'Italian', 'French, Middle (ca.1400-1600)', 'Norwegian', 'Urdu',
#        'Dutch', 'de', 'Finnish', 'Marathi', 'Chinese', 'Swedish',
#        'Icelandic', 'Malayalam', 'ar', 'Croatian', 'Estonian',
#        'Greek, Modern (1453-)', 'Russian', 'no', 'fa', 'fr', 'Kurdish',
#        'Danish', 'Hindi', 'ro', 'Filipino; Pilipino', 'Serbian',
#        'Bengali', 'Malay', 'Catalan; Valencian', 'Czech', 'Vietnamese',
#        'pt-BR', 'Armenian', 'Georgian', 'Kannada', 'Korean', 'sv',
#        'Nepali', 'Telugu', 'Hungarian', 'English, Middle (1100-1500)',
#        'Farsi', 'Lithuanian', 'Ukrainian',
#        'Bokmål, Norwegian; Norwegian Bokmål', 'Slovak', 'ja', 'es',
#        'Faroese', 'Basque', 'id', 'Macedonian', 'Maltese', 'pl',
#        'Amharic', 'gu', 'tr', 'nl', 'bg', 'ms', 'Assamese', 'Gujarati',
#        'Panjabi; Punjabi', 'zh-CN', 'Albanian', 'Latvian', 'Bosnian',
#        'vi', 'fi', 'Thai', 'lt', 'sq', 'it',
#        'Dutch, Middle (ca.1050-1350)', 'Mongolian', 'Tagalog', 'hu', 'cs',
#        'Galician', 'tl', 'da', 'Aleut', 'Slovenian', 'Undetermined',
#        'Greek, Ancient (to 1453)', 'Mayan languages', 'ca', 'Duala',
#        'Australian languages', 'ru',
#        'Norwegian Nynorsk; Nynorsk, Norwegian', 'Afrikaans', 'ko', 'gl',
#        'un'], dtype=object)

# %% [markdown]
# Ponemos todos los idiomas en el mismo formato

# %%
language_map = {
    'english': 'en',
    'english, middle (1100-1500)': 'en',
    'french': 'fr',
    'french, middle (ca.1400-1600)': 'fr',
    'german': 'de',
    'de': 'de',
    'persian': 'fa',
    'farsi': 'fa',
    'fa': 'fa',
    'arabic': 'ar',
    'ar': 'ar',
    'spanish': 'es',
    'es': 'es',
    'multiple languages': 'mul',
    'portuguese': 'pt',
    'pt-br': 'pt',
    'italian': 'it',
    'it': 'it',
    'romanian': 'ro',
    'ro': 'ro',
    'turkish': 'tr',
    'tr': 'tr',
    'polish': 'pl',
    'pl': 'pl',
    'bulgarian': 'bg',
    'bg': 'bg',
    'tamil': 'ta',
    'ta': 'ta',
    'japanese': 'ja',
    'ja': 'ja',
    'norwegian': 'no',
    'bokmål, norwegian; norwegian bokmål': 'no',
    'norwegian nynorsk; nynorsk, norwegian': 'no',
    'no': 'no',
    'urdu': 'ur',
    'dutch': 'nl',
    'dutch, middle (ca.1050-1350)': 'nl',
    'nl': 'nl',
    'finnish': 'fi',
    'fi': 'fi',
    'marathi': 'mr',
    'chinese': 'zh',
    'zh-cn': 'zh',
    'swedish': 'sv',
    'sv': 'sv',
    'icelandic': 'is',
    'malayalam': 'ml',
    'croatian': 'hr',
    'estonian': 'et',
    'greek, modern (1453-)': 'el',
    'greek, ancient (to 1453)': 'grc',
    'russian': 'ru',
    'ru': 'ru',
    'kurdish': 'ku',
    'danish': 'da',
    'da': 'da',
    'hindi': 'hi',
    'filipino; pilipino': 'tl',
    'tagalog': 'tl',
    'tl': 'tl',
    'serbian': 'sr',
    'sr': 'sr',
    'bengali': 'bn',
    'malay': 'ms',
    'ms': 'ms',
    'catalan; valencian': 'ca',
    'ca': 'ca',
    'czech': 'cs',
    'cs': 'cs',
    'vietnamese': 'vi',
    'vi': 'vi',
    'armenian': 'hy',
    'georgian': 'ka',
    'kannada': 'kn',
    'korean': 'ko',
    'ko': 'ko',
    'nepali': 'ne',
    'slovak': 'sk',
    'telugu': 'te',
    'hungarian': 'hu',
    'hu': 'hu',
    'azerbaijani': 'az',
    'lithuanian': 'lt',
    'lt': 'lt',
    'ukrainian': 'uk',
    'iranian (other)': 'fa',
    'faroese': 'fo',
    'basque': 'eu',
    'indonesian': 'id',
    'id': 'id',
    'macedonian': 'mk',
    'maltese': 'mt',
    'gujarati': 'gu',
    'gu': 'gu',
    'amharic': 'am',
    'sq': 'sq',
    'assamese': 'as',
    'panjabi; punjabi': 'pa',
    'albanian': 'sq',
    'latvian': 'lv',
    'bosnian': 'bs',
    'thai': 'th',
    'th': 'th',
    'afrikaans': 'af',
    'mongolian': 'mn',
    'galician': 'gl',
    'gl': 'gl',
    'slovenian': 'sl',
    'sl': 'sl',
    'aromanian; arumanian; macedo-romanian': 'rup',
    'may languages': 'myn',
    'australian languages': 'aus',
    'duala': 'dua',
    'aleut': 'ale',
    'un': 'und',
    'undetermined': 'und'
}

def normalizar_idioma(valor):
    if pd.isna(valor):
        return None
    clave = str(valor).strip().lower()
    return language_map.get(clave, 'und')  
df['language'] = df['language'].apply(normalizar_idioma)

# %%
#los valores nulos los pasamos a 'und' también
df['language'].fillna('und', inplace=True)

# %% [markdown]
# # BookFormat

# %%
df['bookFormat'].value_counts()
# Out:
# bookFormat
# Paperback                26406
# Hardcover                12068
# Kindle Edition            5767
# Mass Market Paperback     2549
# ebook                     2525
#                          ...
# Paperback, eBook             1
# paper book                   1
# Bonded Leather               1
# ebook and paperback          1
# pamphlet                     1
# Name: count, Length: 132, dtype: int64

# %%
#los nulos lo cambiamos a Paperback (tapa blanda) para cambiarlo por la media
df['bookFormat'].fillna("Paperback", inplace=True)

# %%
df['bookFormat'].value_counts()
# Out:
# bookFormat
# Paperback                46958
# Hardcover                12068
# Kindle Edition            5767
# Mass Market Paperback     2549
# ebook                     2525
#                          ...
# Paperback, eBook             1
# paper book                   1
# Bonded Leather               1
# ebook and paperback          1
# pamphlet                     1
# Name: count, Length: 132, dtype: int64

# %% [markdown]
# # Pages

# %%
df['pages'].value_counts()
# Out:
# pages
# 0.0       1560
# 0.0       1485
# 320       1053
# 352        890
# 288        870
#           ...
# 2554.0       1
# 1580.0       1
# 2060.0       1
# 856.0        1
# 633.0        1
# Name: count, Length: 3293, dtype: int64

# %% [markdown]
# Vamos a eliminar las filas con valores nulos y valores = 0 y convertimos la columna a enteros para que tengan el mismo formato

# %%
df = df[df['pages'].notna()]
df['pages'] = df['pages'].astype(str)
df['pages'] = df['pages'].str.extract('(\d+)')
df = df[df['pages'].notna()]
df['pages'] = df['pages'].astype(int)
df = df[df['pages'] != 0]

# %%
df['pages'].value_counts()
# Out:
# pages
# 320      1108
# 352       957
# 288       922
# 304       853
# 256       843
#          ...
# 1640        1
# 11095       1
# 1203        1
# 1286        1
# 1266        1
# Name: count, Length: 1553, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 66237 entries, 0 to 74788
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             66237 non-null  object
#  1   series            66237 non-null  object
#  2   author            66237 non-null  object
#  3   rating            51133 non-null  float64
#  4   description       66237 non-null  object
#  5   language          66237 non-null  object
#  6   genres            66237 non-null  object
#  7   characters        13613 non-null  object
#  8   bookFormat        66237 non-null  object
#  9   pages             66237 non-null  int32
#  10  publisher         62126 non-null  object
#  11  publishDate       66091 non-null  object
#  12  firstPublishDate  46266 non-null  object
#  13  awards            10536 non-null  object
#  14  numRatings        51133 non-null  float64
#  15  likedPercent      49672 non-null  float64
#  16  setting           11454 non-null  object
#  17  coverImg          64517 non-null  object
# dtypes: float64(3), int32(1), object(14)
# memory usage: 9.3+ MB

# %% [markdown]
# # Publisher

# %% [markdown]
# Miramos los nulos

# %%
df['publisher'].isna().sum()
# Out:
# 4111

# %%
df = df[df['publisher'].notna()]

# %%
df['publisher'].value_counts()
# Out:
# publisher
# HarperCollins                                  640
# Vintage                                        576
# Createspace Independent Publishing Platform    446
# Penguin Books                                  426
# Ballantine Books                               397
#                                               ...
# Mullen Press                                     1
# Phal Publishing                                  1
# Yellow Kite                                      1
# Battered Suitcase Press                          1
# Wildflower Isle                                  1
# Name: count, Length: 12851, dtype: int64

# %% [markdown]
# # publishDate

# %%
df['publishDate'].isna().sum()
# Out:
# 3

# %%
df['publishDate'] = pd.to_datetime(df['publishDate'], errors='coerce')
# Out:
# C:\Users\elena\AppData\Local\Temp\ipykernel_16316\171273950.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['publishDate'] = pd.to_datetime(df['publishDate'], errors='coerce')
# C:\Users\elena\AppData\Local\Temp\ipykernel_16316\171273950.py:1: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df['publishDate'] = pd.to_datetime(df['publishDate'], errors='coerce')

# %%
df = df[df['publishDate'].notna()]

# %% [markdown]
# Las guardamos con el mismo fomato

# %%
df['publishDate'].apply(type).value_counts()
# Out:
# publishDate
# <class 'datetime.datetime'>    61568
# Name: count, dtype: int64

# %% [markdown]
# # firstPublishDate

# %%
df['firstPublishDate'].isna().sum()
# Out:
# 18325

# %% [markdown]
# Cambiamos la columna por booleanos para saber si ha habido o no otra edicion

# %%
df['firstPublishDate'] = df['firstPublishDate'].notna()

# %% [markdown]
# # Awards

# %% [markdown]
# Cambiamos la columna por booleanos para saber si ha sido premiado o no

# %%
df['awards'] = df['awards'].notna()

# %%
df
# Out:
#                                            title                 series  \
# 0                               The Hunger Games    The Hunger Games #1
# 1      Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                          To Kill a Mockingbird  To Kill a Mockingbird
# 3                            Pride and Prejudice       Standalone Novel
# 4                                       Twilight   The Twilight Saga #1
# ...                                          ...                    ...
# 74779    Beasts & Behemoths (Dungeons & Dragons)       Standalone Novel
# 74780                   Faculty of Dragon Riders       Standalone Novel
# 74786                      Midnight Delivery Sex       Standalone Novel
# 74787                            Monster Girl: 2       Standalone Novel
# 74788                        La saison du soleil       Standalone Novel
#
#                                                   author  rating  \
# 0                                        Suzanne Collins    4.33
# 1              J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                             Harper Lee    4.28
# 3              Jane Austen, Anna Quindlen (Introduction)    4.26
# 4                                        Stephenie Meyer    3.60
# ...                                                  ...     ...
# 74779  Jim Zub, Stacy King, Andrew Wheeler, Official ...     NaN
# 74780                                     Dmitry Nazarov     NaN
# 74786                                    Neneko Narazaki     NaN
# 74787                                     Kazuki Funatsu     NaN
# 74788                                  Shintaro Ishihara     NaN
#
#                                              description language  \
# 0      WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...       en
# 1      There is a door at the end of a silent corrido...       en
# 2      The unforgettable novel of a childhood in a sl...       en
# 3      Alternate cover edition of ISBN 9780679783268S...       en
# 4      About three things I was absolutely positive.\...       en
# ...                                                  ...      ...
# 74779  Study this guide and keep it close at hand--th...      und
# 74780  I tamed the Black Dragon!So I thought until I ...      und
# 74786  Mit SNS-Card zum Sammeln in der ersten Auflage...       de
# 74787  Dopo il loro incontro, Yatsuki si ritrova ad a...       it
# 74788  Lauréat du prestigieux prix Akutagawa en 1955,...      und
#
#                                                   genres  \
# 0      ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...
# 1      ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 2      ['Classics', 'Fiction', 'Historical Fiction', ...
# 3      ['Classics', 'Fiction', 'Romance', 'Historical...
# 4      ['Young Adult', 'Fantasy', 'Romance', 'Vampire...
# ...                                                  ...
# 74779              Juvenile Nonfiction - dragons romance
# 74780                          Fiction - dragons romance
# 74786                     Comics & Graphic Novels - yaoi
# 74787            Comics & Graphic Novels - isekai comedy
# 74788          Literary Collections - isekai space opera
#
#                                               characters bookFormat  pages  \
# 0      ['Katniss Everdeen', 'Peeta Mellark', 'Cato (H...  Hardcover    374
# 1      ['Sirius Black', 'Draco Malfoy', 'Ron Weasley'...  Paperback    870
# 2      ['Scout Finch', 'Atticus Finch', 'Jem Finch', ...  Paperback    324
# 3      ['Mr. Bennet', 'Mrs. Bennet', 'Jane Bennet', '...  Paperback    279
# 4      ['Edward Cullen', 'Jacob Black', 'Laurent', 'R...  Paperback    501
# ...                                                  ...        ...    ...
# 74779                                                NaN  Paperback    114
# 74780                                                NaN  Paperback    401
# 74786                                                NaN  Paperback     29
# 74787                                                NaN  Paperback    216
# 74788                                                NaN  Paperback    131
#
#                               publisher          publishDate  \
# 0                      Scholastic Press  2008-09-14 00:00:00
# 1                       Scholastic Inc.  2004-09-28 00:00:00
# 2      Harper Perennial Modern Classics  2006-05-23 00:00:00
# 3                        Modern Library  2000-10-10 00:00:00
# 4             Little, Brown and Company  2006-09-06 00:00:00
# ...                                 ...                  ...
# 74779                   Ten Speed Press  2020-10-20 00:00:00
# 74780                            Litres  2022-08-24 00:00:00
# 74786                          Hayabusa  2021-05-04 00:00:00
# 74787                       Edizioni BD  2020-05-01 00:00:00
# 74788                           Belfond  2022-01-27 00:00:00
#
#        firstPublishDate  awards  numRatings  likedPercent  \
# 0                 False    True   6376780.0          96.0
# 1                  True    True   2507623.0          98.0
# 2                  True    True   4501075.0          95.0
# 3                  True   False   2998241.0          94.0
# 4                  True    True   4964519.0          78.0
# ...                 ...     ...         ...           ...
# 74779              True   False         NaN           NaN
# 74780              True   False         NaN           NaN
# 74786              True   False         NaN           NaN
# 74787              True   False         NaN           NaN
# 74788              True   False         NaN           NaN
#
#                                                  setting  \
# 0      ['District 12, Panem', 'Capitol, Panem', 'Pane...
# 1      ['Hogwarts School of Witchcraft and Wizardry (...
# 2                   ['Maycomb, Alabama (United States)']
# 3      ['United Kingdom', 'Derbyshire, England (Unite...
# 4      ['Forks, Washington (United States)', 'Phoenix...
# ...                                                  ...
# 74779                                                NaN
# 74780                                                NaN
# 74786                                                NaN
# 74787                                                NaN
# 74788                                                NaN
#
#                                                 coverImg
# 0      https://i.gr-assets.com/images/S/compressed.ph...
# 1      https://i.gr-assets.com/images/S/compressed.ph...
# 2      https://i.gr-assets.com/images/S/compressed.ph...
# 3      https://i.gr-assets.com/images/S/compressed.ph...
# 4      https://i.gr-assets.com/images/S/compressed.ph...
# ...                                                  ...
# 74779  http://books.google.com/books/content?id=1toui...
# 74780  http://books.google.com/books/content?id=QSGFE...
# 74786  http://books.google.com/books/content?id=s_8_E...
# 74787  http://books.google.com/books/content?id=_yjnE...
# 74788  http://books.google.com/books/content?id=bjZVE...
#
# [61568 rows x 18 columns]

# %% [markdown]
# # coverImg

# %%
df['coverImg'].isna().sum()
# Out:
# 1203

# %% [markdown]
# Elimianmos las filas con valores nulos

# %%
df = df[df['coverImg'].notna()]

# %% [markdown]
# # numRatings, likedPercent, setting, characters

# %% [markdown]
# Se borran porque faltan muchois datos

# %%
df.drop(columns=['numRatings', 'likedPercent', 'setting', 'characters'], inplace=True)
# Out:
# C:\Users\elena\AppData\Local\Temp\ipykernel_16316\3847056173.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['numRatings', 'likedPercent', 'setting', 'characters'], inplace=True)

# %%
df
# Out:
#                                            title                 series  \
# 0                               The Hunger Games    The Hunger Games #1
# 1      Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                          To Kill a Mockingbird  To Kill a Mockingbird
# 3                            Pride and Prejudice       Standalone Novel
# 4                                       Twilight   The Twilight Saga #1
# ...                                          ...                    ...
# 74779    Beasts & Behemoths (Dungeons & Dragons)       Standalone Novel
# 74780                   Faculty of Dragon Riders       Standalone Novel
# 74786                      Midnight Delivery Sex       Standalone Novel
# 74787                            Monster Girl: 2       Standalone Novel
# 74788                        La saison du soleil       Standalone Novel
#
#                                                   author  rating  \
# 0                                        Suzanne Collins    4.33
# 1              J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                             Harper Lee    4.28
# 3              Jane Austen, Anna Quindlen (Introduction)    4.26
# 4                                        Stephenie Meyer    3.60
# ...                                                  ...     ...
# 74779  Jim Zub, Stacy King, Andrew Wheeler, Official ...     NaN
# 74780                                     Dmitry Nazarov     NaN
# 74786                                    Neneko Narazaki     NaN
# 74787                                     Kazuki Funatsu     NaN
# 74788                                  Shintaro Ishihara     NaN
#
#                                              description language  \
# 0      WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...       en
# 1      There is a door at the end of a silent corrido...       en
# 2      The unforgettable novel of a childhood in a sl...       en
# 3      Alternate cover edition of ISBN 9780679783268S...       en
# 4      About three things I was absolutely positive.\...       en
# ...                                                  ...      ...
# 74779  Study this guide and keep it close at hand--th...      und
# 74780  I tamed the Black Dragon!So I thought until I ...      und
# 74786  Mit SNS-Card zum Sammeln in der ersten Auflage...       de
# 74787  Dopo il loro incontro, Yatsuki si ritrova ad a...       it
# 74788  Lauréat du prestigieux prix Akutagawa en 1955,...      und
#
#                                                   genres bookFormat  pages  \
# 0      ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...  Hardcover    374
# 1      ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...  Paperback    870
# 2      ['Classics', 'Fiction', 'Historical Fiction', ...  Paperback    324
# 3      ['Classics', 'Fiction', 'Romance', 'Historical...  Paperback    279
# 4      ['Young Adult', 'Fantasy', 'Romance', 'Vampire...  Paperback    501
# ...                                                  ...        ...    ...
# 74779              Juvenile Nonfiction - dragons romance  Paperback    114
# 74780                          Fiction - dragons romance  Paperback    401
# 74786                     Comics & Graphic Novels - yaoi  Paperback     29
# 74787            Comics & Graphic Novels - isekai comedy  Paperback    216
# 74788          Literary Collections - isekai space opera  Paperback    131
#
#                               publisher          publishDate  \
# 0                      Scholastic Press  2008-09-14 00:00:00
# 1                       Scholastic Inc.  2004-09-28 00:00:00
# 2      Harper Perennial Modern Classics  2006-05-23 00:00:00
# 3                        Modern Library  2000-10-10 00:00:00
# 4             Little, Brown and Company  2006-09-06 00:00:00
# ...                                 ...                  ...
# 74779                   Ten Speed Press  2020-10-20 00:00:00
# 74780                            Litres  2022-08-24 00:00:00
# 74786                          Hayabusa  2021-05-04 00:00:00
# 74787                       Edizioni BD  2020-05-01 00:00:00
# 74788                           Belfond  2022-01-27 00:00:00
#
#        firstPublishDate  awards  \
# 0                 False    True
# 1                  True    True
# 2                  True    True
# 3                  True   False
# 4                  True    True
# ...                 ...     ...
# 74779              True   False
# 74780              True   False
# 74786              True   False
# 74787              True   False
# 74788              True   False
#
#                                                 coverImg
# 0      https://i.gr-assets.com/images/S/compressed.ph...
# 1      https://i.gr-assets.com/images/S/compressed.ph...
# 2      https://i.gr-assets.com/images/S/compressed.ph...
# 3      https://i.gr-assets.com/images/S/compressed.ph...
# 4      https://i.gr-assets.com/images/S/compressed.ph...
# ...                                                  ...
# 74779  http://books.google.com/books/content?id=1toui...
# 74780  http://books.google.com/books/content?id=QSGFE...
# 74786  http://books.google.com/books/content?id=s_8_E...
# 74787  http://books.google.com/books/content?id=_yjnE...
# 74788  http://books.google.com/books/content?id=bjZVE...
#
# [60365 rows x 14 columns]

# %% [markdown]
# Faltaría por hacer la columna de rating y genres

# %% [markdown]
# Faltaria hacer one hot encoding y pasarlo todo a numérico

# %% [markdown]
# # genre

# %% [markdown]
# Hemos separado por comas y quitado los corchetes de los géneros y hemos excluido algunas ccategorías

# %%
excluir = {'nan', 'Pseudocience', 'Christianity', 'Islam', 'Religion', 
           'Buses', 'Emergency Services', 'Paranoid schizophrenia', 'audiobook'}

def extract_genres(entry):
    géneros = []

    if pd.isna(entry):
        return ""

    if not isinstance(entry, str):
        entry = str(entry)

    try:
        parsed = ast.literal_eval(entry)
    except:
        parsed = [entry.strip("[]")]

    def flatten(item):
        if isinstance(item, list):
            for subitem in item:
                flatten(subitem)
        elif isinstance(item, str):
            partes = re.split(r'[-,]', item)
            géneros.extend([p.strip() for p in partes if p.strip()])
        else:
            géneros.append(str(item).strip())

    flatten(parsed)

    géneros = list(set(géneros))
    géneros = [g for g in géneros if g not in excluir and g != '']

    return ', '.join(géneros)

df['genres'] = df['genres'].apply(extract_genres)
# Out:
# C:\Users\elena\AppData\Local\Temp\ipykernel_16316\2563045898.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['genres'] = df['genres'].apply(extract_genres)

# %%
df = df[df['genres'].notna() & (df['genres'].str.strip() != '')]

# %% [markdown]
# como hay tantas categorías lo que hemos hecho en reunirlas todas en 26 categorías principales. Además hemos puesto como límite que cada fila tenga solo 3 categorías

# %%
def procesar_generos(s):
    if isinstance(s, str):
        s = s.lower()
        s = re.sub(r"[\[\]'\"]", "", s)
        s = re.split(r",\s*|\s*,\s*", s)
        return [g.strip() for g in s if g.strip()]
    return []

df['genres_list'] = df['genres'].apply(procesar_generos)

categorias_principales = set([
    'fiction', 'fantasy', 'romance', 'young adult', 'contemporary',
    'historical', 'lgbt', 'comics', 'nonfiction', 'thriller',
    'classics', 'childrens', 'adventure',
    'high fantasy', 'novels', 'magic', 'dystopia', 
    'paranormal', 'humor', 'crime', 'suspense', 'biography',
    'horror', 'isekai'
])

agrupacion_personalizada = {
    'comics & graphic novels': 'comics',
    'graphic novels': 'comics',
    'young adult fiction': 'young adult',
    'juvenile fiction': 'young adult',
    'literary criticism': 'fiction',
    'social science': 'nonfiction',
    'love': 'romance',
    'romantic': 'romance',
    'magic realism': 'fantasy',
    'dark academia': 'classics',
    'historical romance': 'romance',
    'true crime': 'crime',
    'science': 'fiction',
    'science fiction': 'fiction',
    'ya fantasy': 'young adult',
    'lgbtq': 'lgbt',
    'comedy': 'humor',
    'memoir': 'biography',
    'ghosts': 'horror',
    'witches': 'fantasy',
    'superheroes': 'fantasy',
    'paranormal romance': 'paranormal',
    'erotica': 'romance',
    'gothic': 'horror',
    'occult': 'horror',
    'psychological thriller': 'thriller',
    'crime thriller': 'thriller',
    'sci fi': 'fiction',
    'sci-fi': 'fiction',
    'space opera': 'fiction',
    'picture books': 'childrens',
    'novel': 'novels',
    'dystopian': 'dystopia',
    'supernatural thriller': 'thriller',
    'mystery thriller': 'thriller',
    'school life': 'contemporary',
    'slice of life': 'contemporary',
    'romantic comedy': 'romance',
    'true story': 'nonfiction',
    'ya': 'young adult',
}

generos_isekai = [
    'isekai', 'isekai fantasy', 'isekai romance', 'isekai adventure', 
    'isekai harem', 'isekai reverse harem', 'isekai comedy', 'isekai drama',
    'isekai action', 'isekai fantasy romance', 'isekai slice of life',
    'isekai mystery', 'isekai thriller', 'isekai horror', 'isekai supernatural',
    'isekai sci-fi', 'isekai dystopian', 'isekai post-apocalyptic',
    'isekai historical', 'isekai magical realism', 'isekai steampunk',
    'isekai cyberpunk', 'isekai space opera', 'isekai dark fantasy',
    'isekai high fantasy', 'isekai urban fantasy', 'isekai romantic comedy',
    'isekai fantasy adventure', 'isekai fantasy comedy', 'isekai fantasy drama',
    'isekai fantasy action'
]

for g in generos_isekai:
    agrupacion_personalizada[g] = 'isekai'

def mapear_generos(generos):
    resultado = set()
    for g in generos:
        g = g.strip().lower()
        if g in categorias_principales:
            resultado.add(g)
        elif g in agrupacion_personalizada:
            resultado.add(agrupacion_personalizada[g])
    return sorted(list(resultado)) if resultado else ['fiction']

df['main_categories'] = df['genres_list'].apply(mapear_generos)
# Out:
# C:\Users\elena\AppData\Local\Temp\ipykernel_16316\156912237.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['genres_list'] = df['genres'].apply(procesar_generos)
# C:\Users\elena\AppData\Local\Temp\ipykernel_16316\156912237.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['main_categories'] = df['genres_list'].apply(mapear_generos)

# %%
df['main_categories'] = df['main_categories'].apply(lambda x: x[:3])
# Out:
# C:\Users\elena\AppData\Local\Temp\ipykernel_16316\2863956298.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['main_categories'] = df['main_categories'].apply(lambda x: x[:3])

# %% [markdown]
# Renombramos main_categories a genres y eliminamos las columnas de genres list y main_categories

# %%
df['genres'] = df['main_categories']
df = df.drop(columns=['genres_list', 'main_categories'])
# Out:
# C:\Users\elena\AppData\Local\Temp\ipykernel_16316\3822832918.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['genres'] = df['main_categories']

# %%
df
# Out:
#                                            title                 series  \
# 0                               The Hunger Games    The Hunger Games #1
# 1      Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                          To Kill a Mockingbird  To Kill a Mockingbird
# 3                            Pride and Prejudice       Standalone Novel
# 4                                       Twilight   The Twilight Saga #1
# ...                                          ...                    ...
# 74779    Beasts & Behemoths (Dungeons & Dragons)       Standalone Novel
# 74780                   Faculty of Dragon Riders       Standalone Novel
# 74786                      Midnight Delivery Sex       Standalone Novel
# 74787                            Monster Girl: 2       Standalone Novel
# 74788                        La saison du soleil       Standalone Novel
#
#                                                   author  rating  \
# 0                                        Suzanne Collins    4.33
# 1              J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                             Harper Lee    4.28
# 3              Jane Austen, Anna Quindlen (Introduction)    4.26
# 4                                        Stephenie Meyer    3.60
# ...                                                  ...     ...
# 74779  Jim Zub, Stacy King, Andrew Wheeler, Official ...     NaN
# 74780                                     Dmitry Nazarov     NaN
# 74786                                    Neneko Narazaki     NaN
# 74787                                     Kazuki Funatsu     NaN
# 74788                                  Shintaro Ishihara     NaN
#
#                                              description language  \
# 0      WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...       en
# 1      There is a door at the end of a silent corrido...       en
# 2      The unforgettable novel of a childhood in a sl...       en
# 3      Alternate cover edition of ISBN 9780679783268S...       en
# 4      About three things I was absolutely positive.\...       en
# ...                                                  ...      ...
# 74779  Study this guide and keep it close at hand--th...      und
# 74780  I tamed the Black Dragon!So I thought until I ...      und
# 74786  Mit SNS-Card zum Sammeln in der ersten Auflage...       de
# 74787  Dopo il loro incontro, Yatsuki si ritrova ad a...       it
# 74788  Lauréat du prestigieux prix Akutagawa en 1955,...      und
#
#                                  genres bookFormat  pages  \
# 0        [adventure, dystopia, fantasy]  Hardcover    374
# 1      [adventure, childrens, classics]  Paperback    870
# 2       [classics, fiction, historical]  Paperback    324
# 3       [classics, fiction, historical]  Paperback    279
# 4        [fantasy, fiction, paranormal]  Paperback    501
# ...                                 ...        ...    ...
# 74779                         [fiction]  Paperback    114
# 74780                         [fiction]  Paperback    401
# 74786                          [comics]  Paperback     29
# 74787                  [comics, isekai]  Paperback    216
# 74788                          [isekai]  Paperback    131
#
#                               publisher          publishDate  \
# 0                      Scholastic Press  2008-09-14 00:00:00
# 1                       Scholastic Inc.  2004-09-28 00:00:00
# 2      Harper Perennial Modern Classics  2006-05-23 00:00:00
# 3                        Modern Library  2000-10-10 00:00:00
# 4             Little, Brown and Company  2006-09-06 00:00:00
# ...                                 ...                  ...
# 74779                   Ten Speed Press  2020-10-20 00:00:00
# 74780                            Litres  2022-08-24 00:00:00
# 74786                          Hayabusa  2021-05-04 00:00:00
# 74787                       Edizioni BD  2020-05-01 00:00:00
# 74788                           Belfond  2022-01-27 00:00:00
#
#        firstPublishDate  awards  \
# 0                 False    True
# 1                  True    True
# 2                  True    True
# 3                  True   False
# 4                  True    True
# ...                 ...     ...
# 74779              True   False
# 74780              True   False
# 74786              True   False
# 74787              True   False
# 74788              True   False
#
#                                                 coverImg
# 0      https://i.gr-assets.com/images/S/compressed.ph...
# 1      https://i.gr-assets.com/images/S/compressed.ph...
# 2      https://i.gr-assets.com/images/S/compressed.ph...
# 3      https://i.gr-assets.com/images/S/compressed.ph...
# 4      https://i.gr-assets.com/images/S/compressed.ph...
# ...                                                  ...
# 74779  http://books.google.com/books/content?id=1toui...
# 74780  http://books.google.com/books/content?id=QSGFE...
# 74786  http://books.google.com/books/content?id=s_8_E...
# 74787  http://books.google.com/books/content?id=_yjnE...
# 74788  http://books.google.com/books/content?id=bjZVE...
#
# [57305 rows x 14 columns]

# %% [markdown]
# # Rating

# %% [markdown]
# Para los valores faltantes de rating hemos elaborado un modelo para predecir el resultado en el que con las columnas bookFormat, language, publisher (categóricas) y title, description, genres y author (string) rellenamos los valores nulos al vectorizar el el texto con TF-IDF y entrenamos el modelo con RandomForest

# %%
df_model = df.copy()
def convertir_a_lista(x):
    try:
        return ast.literal_eval(x) if isinstance(x, str) else []
    except:
        return []

df_model['genres'] = df_model['genres'].apply(convertir_a_lista)

cat_cols = ['series', 'language', 'bookFormat']
label_encoders = {}

for col in cat_cols:
    le = LabelEncoder()
    df_model[col] = df_model[col].astype(str).fillna('missing')
    df_model[col] = le.fit_transform(df_model[col])
    label_encoders[col] = le

df_model['awards'] = df_model['awards'].astype(bool)
df_model['firstPublishDate'] = df_model['firstPublishDate'].astype(bool)

author_avg = df_model.groupby('author')['rating'].mean()
df_model['author_rating'] = df_model['author'].map(author_avg)
df_model['author_rating'] = df_model['author_rating'].fillna(df_model['rating'].mean())

mlb = MultiLabelBinarizer()
genres_ohe = mlb.fit_transform(df_model['genres'])
df_genres = pd.DataFrame(genres_ohe, columns=mlb.classes_, index=df_model.index)
df_model = pd.concat([df_model, df_genres], axis=1)

features = ['series', 'language', 'bookFormat', 'firstPublishDate', 'awards', 'author_rating'] + list(df_genres.columns)

df_train = df_model[df_model['rating'].notna()]
df_predict = df_model[df_model['rating'].isna()]

X_train = df_train[features]
y_train = df_train['rating']
X_pred = df_predict[features]

for k in [2]:
    print(f"\nImputando con KNN (k={k})...")
    knn = KNeighborsRegressor(n_neighbors=k)
    knn.fit(X_train, y_train)
    rating_pred = knn.predict(X_pred)
    missing_index = df[df['rating'].isna()].index
    df.loc[missing_index, 'rating'] = rating_pred
    print(f"Ratings imputados con K={k}. Nulos restantes: {df['rating'].isna().sum()}")
# Out:
# Imputando con KNN (k=2)...
# Ratings imputados con K=2. Nulos restantes: 0

# %%
df['rating'] = df['rating'].round(2)

# %%
df
# Out:
#                                            title                 series  \
# 0                               The Hunger Games    The Hunger Games #1
# 1      Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                          To Kill a Mockingbird  To Kill a Mockingbird
# 3                            Pride and Prejudice       Standalone Novel
# 4                                       Twilight   The Twilight Saga #1
# ...                                          ...                    ...
# 74779    Beasts & Behemoths (Dungeons & Dragons)       Standalone Novel
# 74780                   Faculty of Dragon Riders       Standalone Novel
# 74786                      Midnight Delivery Sex       Standalone Novel
# 74787                            Monster Girl: 2       Standalone Novel
# 74788                        La saison du soleil       Standalone Novel
#
#                                                   author  rating  \
# 0                                        Suzanne Collins    4.33
# 1              J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                             Harper Lee    4.28
# 3              Jane Austen, Anna Quindlen (Introduction)    4.26
# 4                                        Stephenie Meyer    3.60
# ...                                                  ...     ...
# 74779  Jim Zub, Stacy King, Andrew Wheeler, Official ...    4.04
# 74780                                     Dmitry Nazarov    4.04
# 74786                                    Neneko Narazaki    4.00
# 74787                                     Kazuki Funatsu    4.00
# 74788                                  Shintaro Ishihara    4.04
#
#                                              description language  \
# 0      WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...       en
# 1      There is a door at the end of a silent corrido...       en
# 2      The unforgettable novel of a childhood in a sl...       en
# 3      Alternate cover edition of ISBN 9780679783268S...       en
# 4      About three things I was absolutely positive.\...       en
# ...                                                  ...      ...
# 74779  Study this guide and keep it close at hand--th...      und
# 74780  I tamed the Black Dragon!So I thought until I ...      und
# 74786  Mit SNS-Card zum Sammeln in der ersten Auflage...       de
# 74787  Dopo il loro incontro, Yatsuki si ritrova ad a...       it
# 74788  Lauréat du prestigieux prix Akutagawa en 1955,...      und
#
#                                  genres bookFormat  pages  \
# 0        [adventure, dystopia, fantasy]  Hardcover    374
# 1      [adventure, childrens, classics]  Paperback    870
# 2       [classics, fiction, historical]  Paperback    324
# 3       [classics, fiction, historical]  Paperback    279
# 4        [fantasy, fiction, paranormal]  Paperback    501
# ...                                 ...        ...    ...
# 74779                         [fiction]  Paperback    114
# 74780                         [fiction]  Paperback    401
# 74786                          [comics]  Paperback     29
# 74787                  [comics, isekai]  Paperback    216
# 74788                          [isekai]  Paperback    131
#
#                               publisher          publishDate  \
# 0                      Scholastic Press  2008-09-14 00:00:00
# 1                       Scholastic Inc.  2004-09-28 00:00:00
# 2      Harper Perennial Modern Classics  2006-05-23 00:00:00
# 3                        Modern Library  2000-10-10 00:00:00
# 4             Little, Brown and Company  2006-09-06 00:00:00
# ...                                 ...                  ...
# 74779                   Ten Speed Press  2020-10-20 00:00:00
# 74780                            Litres  2022-08-24 00:00:00
# 74786                          Hayabusa  2021-05-04 00:00:00
# 74787                       Edizioni BD  2020-05-01 00:00:00
# 74788                           Belfond  2022-01-27 00:00:00
#
#        firstPublishDate  awards  \
# 0                 False    True
# 1                  True    True
# 2                  True    True
# 3                  True   False
# 4                  True    True
# ...                 ...     ...
# 74779              True   False
# 74780              True   False
# 74786              True   False
# 74787              True   False
# 74788              True   False
#
#                                                 coverImg
# 0      https://i.gr-assets.com/images/S/compressed.ph...
# 1      https://i.gr-assets.com/images/S/compressed.ph...
# 2      https://i.gr-assets.com/images/S/compressed.ph...
# 3      https://i.gr-assets.com/images/S/compressed.ph...
# 4      https://i.gr-assets.com/images/S/compressed.ph...
# ...                                                  ...
# 74779  http://books.google.com/books/content?id=1toui...
# 74780  http://books.google.com/books/content?id=QSGFE...
# 74786  http://books.google.com/books/content?id=s_8_E...
# 74787  http://books.google.com/books/content?id=_yjnE...
# 74788  http://books.google.com/books/content?id=bjZVE...
#
# [57305 rows x 14 columns]

# %% [markdown]
# Gráficos para visión general del dataset de libros de ocio: géneros, autores y ratings

# %%
# Distribución de géneros más frecuentes
# Aplanar géneros
all_genres = df['genres'].dropna().apply(ast.literal_eval).sum()
genre_counts = Counter(all_genres)
top_genres = dict(genre_counts.most_common(10))

plt.figure(figsize=(10,5))
plt.bar(top_genres.keys(), top_genres.values(), color='#219EBC')
plt.xticks(rotation=45)
plt.title('Top 10 géneros más frecuentes')
plt.ylabel('Frecuencia')
plt.tight_layout()
plt.show()

# %%
# Autores con más libros en el dataset
top_authors = df['author'].value_counts().head(10)

plt.figure(figsize=(8,5))
top_authors.plot(kind='barh', color='#023047')
plt.title('Autores con más libros en el dataset')
plt.xlabel('Cantidad de libros')
plt.ylabel('Autor')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
# Distribución de valoraciones (rating)
plt.figure(figsize=(8,4))
sns.histplot(df['rating'], kde=True, bins=30, color='#219EBC')
plt.title('Distribución de valoraciones de libros')
plt.xlabel('Rating')
plt.ylabel('Cantidad de libros')
plt.tight_layout()
plt.show()

# %%
# Longitud de las descripciones
df['desc_length'] = df['description'].apply(lambda x: len(x.split()) if isinstance(x, str) else 0)

plt.figure(figsize=(8,4))
sns.histplot(df['desc_length'], bins=50, color='#219EBC')
plt.title('Distribución de la longitud de las descripciones (número de palabras)')
plt.xlabel('Número de palabras')
plt.ylabel('Cantidad de libros')
plt.show()

# %%
# Nube de palabras (Word Cloud)
text = " ".join(df['description'].dropna().tolist())

wordcloud = WordCloud(width=1000, height=600, background_color='white').generate(text)

plt.figure(figsize=(12,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Nube de palabras de las descripciones de libros')
plt.show()

# %%
df.to_csv('../data/final_data/df_web.csv')
