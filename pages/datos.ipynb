# %%
import pandas as pd
df_best_books = pd.read_csv('books_1.Best_Books_Ever.csv')
df_best_books.head()
# Out:
#                                         bookId  \
# 0                     2767052-the-hunger-games
# 1  2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                   2657.To_Kill_a_Mockingbird
# 3                     1885.Pride_and_Prejudice
# 4                               41865.Twilight
#
#                                        title                 series  \
# 0                           The Hunger Games    The Hunger Games #1
# 1  Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                      To Kill a Mockingbird  To Kill a Mockingbird
# 3                        Pride and Prejudice                    NaN
# 4                                   Twilight   The Twilight Saga #1
#
#                                       author  rating  \
# 0                            Suzanne Collins    4.33
# 1  J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                 Harper Lee    4.28
# ...

# %%
import pandas as pd
df_best_books = pd.read_csv('books_enriched_batch_1.csv')
df_best_books.head()
# Out:
#                                         bookId  \
# 0                     2767052-the-hunger-games
# 1  2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                   2657.To_Kill_a_Mockingbird
# 3                     1885.Pride_and_Prejudice
# 4                               41865.Twilight
#
#                                        title                 series  \
# 0                           The Hunger Games    The Hunger Games #1
# 1  Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                      To Kill a Mockingbird  To Kill a Mockingbird
# 3                        Pride and Prejudice                    NaN
# 4                                   Twilight   The Twilight Saga #1
#
#                                       author  rating  \
# 0                            Suzanne Collins    4.33
# 1  J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                 Harper Lee    4.28
# ...

# %%
df_best_books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   bookId            10000 non-null  object
#  1   title             10000 non-null  object
#  2   series            5201 non-null   object
#  3   author            10000 non-null  object
#  4   rating            10000 non-null  float64
#  5   description       9973 non-null   object
#  6   language          9893 non-null   object
#  7   isbn              9904 non-null   object
#  8   genres            10000 non-null  object
#  9   characters        10000 non-null  object
#  10  bookFormat        9919 non-null   object
#  11  edition           1357 non-null   object
#  12  pages             9907 non-null   object
#  13  publisher         9705 non-null   object
#  14  publishDate       9987 non-null   object
#  15  firstPublishDate  6528 non-null   object
# ...

# %%
df_best_books['publishDate'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                 09/14/08
# 1                 09/28/04
# 2                 05/23/06
# 3                 10/10/00
# 4                 09/06/06
#                ...
# 9995    December 29th 1998
# 9996      January 3rd 2006
# 9997        April 1st 2005
# 9998        April 1st 2005
# 9999                  2009
# Name: publishDate, Length: 10000, dtype: object>

# %%
df_best_books.shape
# Out:
# (52478, 25)

# %%
import pandas as pd
import requests
import time

#import pandas as pd
import requests
import time
from requests.exceptions import RequestException

# ======= CONFIGURACIÓN =======
input_file = "books_1.Best_Books_Ever.csv"
lote_tamaño = 10000
espera_segundos = 1  # tiempo entre peticiones
# =============================

def get_google_books_data(title, author=None, isbn=None):
    try:
        if isbn and isbn != '9999999999999':
            query = f'isbn:{isbn}'
        else:
            query = f'intitle:{title}'
            if author:
                query += f'+inauthor:{author}'
        
        url = f'https://www.googleapis.com/books/v1/volumes?q={query}'
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        data = response.json()
        
        if 'items' not in data:
            return None
        
        volume = data['items'][0]['volumeInfo']
        return {
            "isbn": next((id["identifier"] for id in volume.get("industryIdentifiers", []) if id["type"] == "ISBN_13"), None),
            "publisher": volume.get("publisher"),
            "publishDate": volume.get("publishedDate"),
            "pages": volume.get("pageCount"),
            "language": volume.get("language"),
            "description": volume.get("description"),
            "coverImg": volume.get("imageLinks", {}).get("thumbnail")
        }
    except RequestException as e:
        print(f"Error en '{title}': {e}")
        return None

def update_missing_fields(row):
    needs_update = (
        row['isbn'] == '9999999999999' or
        pd.isna(row['publisher']) or
        pd.isna(row['publishDate']) or
        pd.isna(row['pages']) or
        pd.isna(row['description']) or
        pd.isna(row['coverImg']) or
        pd.isna(row['language'])
    )
    if not needs_update:
        return row
    
    title = row['title']
    author = row['author'].split(',')[0] if pd.notna(row['author']) else None
    isbn = row['isbn'] if row['isbn'] != '9999999999999' else None

    data = get_google_books_data(title, author, isbn)
    time.sleep(espera_segundos)

    if data:
        for key, value in data.items():
            if pd.isna(row.get(key)) or (key == 'isbn' and row['isbn'] == '9999999999999'):
                row[key] = value
    return row

# ====== PROCESO POR LOTES ======
df = pd.read_csv(input_file)
total = len(df)
num_lotes = (total // lote_tamaño) + 1

for i in range(num_lotes):
    inicio = i * lote_tamaño
    fin = min((i + 1) * lote_tamaño, total)
    df_lote = df.iloc[inicio:fin].copy()

    print(f"\nProcesando lote {i+1}/{num_lotes} — libros {inicio} a {fin}")

    df_lote_actualizado = df_lote.apply(update_missing_fields, axis=1)

    output_name = f"books_enriched_batch_{i+1}.csv"
    df_lote_actualizado.to_csv(output_name, index=False)
    print(f"Guardado: {output_name}")
# Out:
# Procesando lote 1/6 — libros 0 a 10000
# Error en 'Coexist': HTTPSConnectionPool(host='www.googleapis.com', port=443): Read timed out. (read timeout=10)
# Guardado: books_enriched_batch_1.csv
#
# Procesando lote 2/6 — libros 10000 a 20000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 85
#      81 df_lote = df.iloc[inicio:fin].copy()
#      83 print(f"\nProcesando lote {i+1}/{num_lotes} — libros {inicio} a {fin}")
# ---> 85 df_lote_actualizado = df_lote.apply(update_missing_fields, axis=1)
#      87 output_name = f"books_enriched_batch_{i+1}.csv"
#      88 df_lote_actualizado.to_csv(output_name, index=False)
#
# File c:\Users\elena\anaconda3\Lib\site-packages\pandas\core\frame.py:10034, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10022 from pandas.core.apply import frame_apply
#   10024 op = frame_apply(
# ...

# %%
import pandas as pd
import requests
import time
import os
from requests.exceptions import RequestException

# ========== CONFIGURACIÓN ==========
input_file = "books_1.Best_Books_Ever.csv"  # tu archivo CSV original
lote_tamaño = 10000                        # libros por lote
espera_segundos = 1                        # espera entre peticiones
# ====================================

# Función para consultar Google Books API
def get_google_books_data(title, author=None, isbn=None):
    try:
        if isbn and isbn != '9999999999999':
            query = f'isbn:{isbn}'
        else:
            query = f'intitle:{title}'
            if author:
                query += f'+inauthor:{author}'
        
        url = f'https://www.googleapis.com/books/v1/volumes?q={query}'
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        data = response.json()
        
        if 'items' not in data:
            return None
        
        volume = data['items'][0]['volumeInfo']
        return {
            "isbn": next((id["identifier"] for id in volume.get("industryIdentifiers", []) if id["type"] == "ISBN_13"), None),
            "publisher": volume.get("publisher"),
            "publishDate": volume.get("publishedDate"),
            "pages": volume.get("pageCount"),
            "language": volume.get("language"),
            "description": volume.get("description"),
            "coverImg": volume.get("imageLinks", {}).get("thumbnail")
        }
    except RequestException as e:
        print(f"⚠️ Error en '{title}': {e}")
        return None

# Función para actualizar campos faltantes
def update_missing_fields(row):
    needs_update = (
        row['isbn'] == '9999999999999' or
        pd.isna(row['publisher']) or
        pd.isna(row['publishDate']) or
        pd.isna(row['pages']) or
        pd.isna(row['description']) or
        pd.isna(row['coverImg']) or
        pd.isna(row['language'])
    )
    if not needs_update:
        return row
    
    title = row['title']
    author = row['author'].split(',')[0] if pd.notna(row['author']) else None
    isbn = row['isbn'] if row['isbn'] != '9999999999999' else None

    data = get_google_books_data(title, author, isbn)
    time.sleep(espera_segundos)

    if data:
        for key, value in data.items():
            if pd.isna(row.get(key)) or (key == 'isbn' and row['isbn'] == '9999999999999'):
                row[key] = value
    return row

# ====== PROCESO POR LOTES ======
print("🔍 Cargando archivo CSV...")
df = pd.read_csv(input_file)
total = len(df)
num_lotes = (total // lote_tamaño) + 1

# Detectar desde qué lote continuar automáticamente
procesados = [f"books_enriched_batch_{i+1}.csv" for i in range(num_lotes)]
lote_inicial = next((i for i, nombre in enumerate(procesados) if not os.path.exists(nombre)), num_lotes)

if lote_inicial >= num_lotes:
    print("✅ Todos los lotes ya están procesados.")
else:
    print(f"🚀 Empezando desde el lote {lote_inicial + 1}/{num_lotes}...")

for i in range(lote_inicial, num_lotes):
    inicio = i * lote_tamaño
    fin = min((i + 1) * lote_tamaño, total)
    df_lote = df.iloc[inicio:fin].copy()

    print(f"\n🔄 Procesando lote {i+1}/{num_lotes} — libros {inicio} a {fin}")

    df_lote_actualizado = df_lote.apply(update_missing_fields, axis=1)

    output_name = f"books_enriched_batch_{i+1}.csv"
    df_lote_actualizado.to_csv(output_name, index=False)
    print(f"✅ Guardado: {output_name}")

print("\n🎉 Proceso completado.")
# Out:
# 🔍 Cargando archivo CSV...
# 🚀 Empezando desde el lote 2/6...
#
# 🔄 Procesando lote 2/6 — libros 10000 a 20000
# ✅ Guardado: books_enriched_batch_2.csv
#
# 🔄 Procesando lote 3/6 — libros 20000 a 30000
# ✅ Guardado: books_enriched_batch_3.csv
#
# 🔄 Procesando lote 4/6 — libros 30000 a 40000

# %%
import pandas as pd
import requests, time, os
from requests.exceptions import RequestException
import numpy as np   # por si sigues usando limpieza de nulos más adelante

# ========== CONFIGURACIÓN ==========
input_file    = "books_1.Best_Books_Ever.csv"
lote_tamaño   = 10_000
espera_segundos = 1

### NUEVO: fila (0-based) a partir de la que quieres continuar ------------
start_row = 40_000      # 40 000 → saltas los 40 000 primeros registros
# -------------------------------------------------------------------------

# ---------- FUNCIONES (idénticas a tu versión) ---------------------------
def get_google_books_data(title, author=None, isbn=None):
    try:
        if isbn and isbn != '9999999999999':
            query = f'isbn:{isbn}'
        else:
            query = f'intitle:{title}'
            if author:
                query += f'+inauthor:{author}'
        url = f'https://www.googleapis.com/books/v1/volumes?q={query}'
        r = requests.get(url, timeout=10)
        r.raise_for_status()
        data = r.json()
        if 'items' not in data:
            return None
        v = data['items'][0]['volumeInfo']
        return {
            "isbn": next((i["identifier"] for i in v.get("industryIdentifiers", [])
                          if i["type"] == "ISBN_13"), None),
            "publisher":    v.get("publisher"),
            "publishDate":  v.get("publishedDate"),
            "pages":        v.get("pageCount"),
            "language":     v.get("language"),
            "description":  v.get("description"),
            "coverImg":     v.get("imageLinks", {}).get("thumbnail")
        }
    except RequestException as e:
        print(f"⚠️ Error en '{title}': {e}")
        return None

def update_missing_fields(row):
    needs = (
        row['isbn'] == '9999999999999' or
        pd.isna(row['publisher']) or pd.isna(row['publishDate']) or
        pd.isna(row['pages']) or pd.isna(row['description']) or
        pd.isna(row['coverImg']) or pd.isna(row['language'])
    )
    if not needs:
        return row
    title  = row['title']
    author = row['author'].split(',')[0] if pd.notna(row['author']) else None
    isbn   = row['isbn'] if row['isbn'] != '9999999999999' else None
    data   = get_google_books_data(title, author, isbn)
    time.sleep(espera_segundos)
    if data:
        for k, v in data.items():
            if pd.isna(row.get(k)) or (k == 'isbn' and row['isbn'] == '9999999999999'):
                row[k] = v
    return row
# -------------------------------------------------------------------------

print("🔍 Cargando CSV…")
df = pd.read_csv(input_file)
total     = len(df)
num_lotes = (total // lote_tamaño) + 1

### NUEVO: lote en el que se encuentra start_row --------------------------
lote_inicial = start_row // lote_tamaño
print(f"🚀 Procesaremos desde el lote {lote_inicial + 1} "
      f"(fila {start_row:,} de {total:,}).")
# -------------------------------------------------------------------------

for i in range(lote_inicial, num_lotes):
    inicio = i * lote_tamaño
    fin    = min((i + 1) * lote_tamaño, total)
    if fin <= start_row:       # por si start_row no cae justo al inicio
        continue

    df_lote = df.iloc[inicio:fin].copy()
    print(f"\n🔄 Lote {i+1}/{num_lotes} — filas {inicio:,} → {fin-1:,}")

    df_lote_act = df_lote.apply(update_missing_fields, axis=1)

    out = f"books_enriched_batch_{i+1}.csv"
    df_lote_act.to_csv(out, index=False)
    print(f"✅ Guardado: {out}")

print("\n🎉 Proceso completado.")
# Out:
# 🔍 Cargando CSV…
# 🚀 Procesaremos desde el lote 5 (fila 40,000 de 52,478).
#
# 🔄 Lote 5/6 — filas 40,000 → 49,999
# ✅ Guardado: books_enriched_batch_5.csv
#
# 🔄 Lote 6/6 — filas 50,000 → 52,477
# ✅ Guardado: books_enriched_batch_6.csv
#
# 🎉 Proceso completado.

# %%
import pandas as pd
import requests, time
from requests.exceptions import RequestException

# ========== CONFIGURACIÓN ==========
input_file = "books_1.Best_Books_Ever.csv"
output_file = "books_enriched_30000_40000.csv"
start_row = 30000
end_row = 40000
espera_segundos = 1
# ===================================

def get_google_books_data(title, author=None, isbn=None):
    try:
        if isbn and isbn != '9999999999999':
            query = f'isbn:{isbn}'
        else:
            query = f'intitle:{title}'
            if author:
                query += f'+inauthor:{author}'
        url = f'https://www.googleapis.com/books/v1/volumes?q={query}'
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        data = response.json()
        if 'items' not in data:
            return None
        v = data['items'][0]['volumeInfo']
        return {
            "isbn": next((i["identifier"] for i in v.get("industryIdentifiers", [])
                          if i["type"] == "ISBN_13"), None),
            "publisher":    v.get("publisher"),
            "publishDate":  v.get("publishedDate"),
            "pages":        v.get("pageCount"),
            "language":     v.get("language"),
            "description":  v.get("description"),
            "coverImg":     v.get("imageLinks", {}).get("thumbnail")
        }
    except RequestException as e:
        print(f"⚠️ Error en '{title}': {e}")
        return None

def update_missing_fields(row):
    needs = (
        row['isbn'] == '9999999999999' or
        pd.isna(row['publisher']) or pd.isna(row['publishDate']) or
        pd.isna(row['pages']) or pd.isna(row['description']) or
        pd.isna(row['coverImg']) or pd.isna(row['language'])
    )
    if not needs:
        return row
    title  = row['title']
    author = row['author'].split(',')[0] if pd.notna(row['author']) else None
    isbn   = row['isbn'] if row['isbn'] != '9999999999999' else None
    data   = get_google_books_data(title, author, isbn)
    time.sleep(espera_segundos)
    if data:
        for k, v in data.items():
            if pd.isna(row.get(k)) or (k == 'isbn' and row['isbn'] == '9999999999999'):
                row[k] = v
    return row

# === CARGA Y PROCESAMIENTO DEL RANGO ===
print(f"🔍 Cargando CSV desde fila {start_row:,} hasta {end_row-1:,}…")
df = pd.read_csv(input_file)

# Extraer solo las filas del 30.000 al 39.999
df_lote = df.iloc[start_row:end_row].copy()
print(f"🔄 Procesando lote de {len(df_lote):,} libros…")

df_lote_actualizado = df_lote.apply(update_missing_fields, axis=1)

# Guardar resultado
df_lote_actualizado.to_csv(output_file, index=False)
print(f"✅ Guardado: {output_file}")
# Out:
# 🔍 Cargando CSV desde fila 30,000 hasta 39,999…
# 🔄 Procesando lote de 10,000 libros…
# ✅ Guardado: books_enriched_30000_40000.csv

# %%
import pandas as pd
import os

# Lista de archivos a combinar (ajusta si hay más)
archivos = [
    "books_enriched_batch_1.csv",
    "books_enriched_batch_2.csv",
    "books_enriched_batch_3.csv",
    "books_enriched_30000_40000.csv",
    "books_enriched_batch_5.csv",
    "books_enriched_batch_6.csv",
]

# Leer y concatenar todos
dataframes = [pd.read_csv(archivo) for archivo in archivos]
df_final = pd.concat(dataframes, ignore_index=True)

# Guardar en un nuevo archivo
df_final.to_csv("books_enriched_full.csv", index=False)
print("✅ Archivo combinado guardado como 'books_enriched_full.csv'")
# Out:
# ✅ Archivo combinado guardado como 'books_enriched_full.csv'

# %%
import pandas as pd

df_full = pd.read_csv('books_enriched_full.csv')
df_full
# Out:
#                                             bookId  \
# 0                         2767052-the-hunger-games
# 1      2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                       2657.To_Kill_a_Mockingbird
# 3                         1885.Pride_and_Prejudice
# 4                                   41865.Twilight
# ...                                            ...
# 52473                           11492014-fractured
# 52474                             11836711-anasazi
# 52475                              10815662-marked
# 52476                         11330278-wayward-son
# 52477                 10991547-daughter-of-helaman
#
#                                            title                 series  \
# 0                               The Hunger Games    The Hunger Games #1
# 1      Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                          To Kill a Mockingbird  To Kill a Mockingbird
# ...

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52478 entries, 0 to 52477
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   bookId            52478 non-null  object
#  1   title             52478 non-null  object
#  2   series            23470 non-null  object
#  3   author            52478 non-null  object
#  4   rating            52478 non-null  float64
#  5   description       51611 non-null  object
#  6   language          51231 non-null  object
#  7   isbn              51717 non-null  object
#  8   genres            52478 non-null  object
#  9   characters        52478 non-null  object
#  10  bookFormat        51005 non-null  object
#  11  edition           4955 non-null   object
#  12  pages             51171 non-null  object
#  13  publisher         49472 non-null  object
#  14  publishDate       52109 non-null  object
#  15  firstPublishDate  31152 non-null  object
# ...

# %%
df_full['publishDate'].value_counts()
# Out:
# publishDate
# Published              586
# 2008                   268
# 2009                   237
# 2007                   231
# 2010                   218
#                       ...
# October 27th 2006        1
# June 11th 2008           1
# October 15th 1973        1
# September 12th 1988      1
# August 21st 2011         1
# Name: count, Length: 10844, dtype: int64

# %%
df_full['firstPublishDate'].value_counts()
# Out:
# firstPublishDate
# 01/01/12          225
# 01/01/10          213
# 01/01/11          212
# 01/01/09          189
# 01/01/08          182
#                  ...
# 04/28/06            1
# 01/18/88            1
# 03/10/05            1
# 04/15/96            1
# April 5th 2011      1
# Name: count, Length: 8024, dtype: int64

# %%
before = len(df_full)
df_full = df_full[df_full['isbn'].notna() & (df_full['isbn'].str.strip() != '')]
after = len(df_full)
print(f"Se eliminaron {before - after} filas sin ISBN.")
# Out:
# Se eliminaron 761 filas sin ISBN.

# %%
import pandas as pd
from dateutil import parser

def safe_parse_date(date):
    try:
        dt = parser.parse(str(date), fuzzy=True)
        if 1700 <= dt.year <= 2100:
            return dt  
        else:
            return pd.NaT
    except:
        return pd.NaT
    
df_full.loc[:, 'publishDate'] = df_full['publishDate'].apply(safe_parse_date)
df_full.loc[:, 'firstPublishDate'] = df_full['firstPublishDate'].apply(safe_parse_date)
print(df_full[['publishDate', 'firstPublishDate']].head())
# Out:
#            publishDate     firstPublishDate
# 0  2008-09-14 00:00:00                  NaT
# 1  2004-09-28 00:00:00  2003-06-21 00:00:00
# 2  2006-05-23 00:00:00  2060-07-11 00:00:00
# 4  2006-09-06 00:00:00  2005-10-05 00:00:00
# 5  2006-03-14 00:00:00  2005-09-01 00:00:00

# %%
df_full
# Out:
#                                             bookId  \
# 0                         2767052-the-hunger-games
# 1      2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                       2657.To_Kill_a_Mockingbird
# 4                                   41865.Twilight
# 5                             19063.The_Book_Thief
# ...                                            ...
# 52473                           11492014-fractured
# 52474                             11836711-anasazi
# 52475                              10815662-marked
# 52476                         11330278-wayward-son
# 52477                 10991547-daughter-of-helaman
#
#                                            title                 series  \
# 0                               The Hunger Games    The Hunger Games #1
# 1      Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                          To Kill a Mockingbird  To Kill a Mockingbird
# ...

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51717 entries, 0 to 52477
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   bookId            51717 non-null  object
#  1   title             51717 non-null  object
#  2   series            23298 non-null  object
#  3   author            51717 non-null  object
#  4   rating            51717 non-null  float64
#  5   description       50962 non-null  object
#  6   language          50470 non-null  object
#  7   isbn              51717 non-null  object
#  8   genres            51717 non-null  object
#  9   characters        51717 non-null  object
#  10  bookFormat        50413 non-null  object
#  11  edition           4818 non-null   object
#  12  pages             50423 non-null  object
#  13  publisher         48813 non-null  object
#  14  publishDate       50544 non-null  object
#  15  firstPublishDate  30711 non-null  object
# ...

# %%
# Ver columnas por posición (20 a 22 inclusive)
df_full.iloc[:, 20:23].isna().sum()
# Out:
# setting       0
# coverImg    363
# bbeScore      0
# dtype: int64

# %%
# Ver cuántas filas tienen algún valor faltante en esas columnas
columnas_objetivo = ['description', 'language', 'bookFormat', 'pages', 'publishDate', 'coverImg']
filas_incompletas = df_full[columnas_objetivo].isna().any(axis=1)
total_incompletas = filas_incompletas.sum()
print(f"Hay {total_incompletas} filas con al menos un dato faltante en las columnas seleccionadas.")
# Out:
# Hay 4258 filas con al menos un dato faltante en las columnas seleccionadas.

# %%
#eliminamos las filas faltanates 
df_full = df_full[~filas_incompletas].copy()

# %%
print(f"Número de filas después de eliminar incompletas: {len(df_full)}")
# Out:
# Número de filas después de eliminar incompletas: 47459

# %%
print(df_full.iloc[0])
# Out:
# bookId                                       2767052-the-hunger-games
# title                                                The Hunger Games
# series                                            The Hunger Games #1
# author                                                Suzanne Collins
# rating                                                           4.33
# description         WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...
# language                                                      English
# isbn                                                    9780439023481
# genres              ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...
# characters          ['Katniss Everdeen', 'Peeta Mellark', 'Cato (H...
# bookFormat                                                  Hardcover
# edition                                                 First Edition
# pages                                                             374
# ...

# %%
print(df_full.iloc[0]['setting'])
# Out:
# ['District 12, Panem', 'Capitol, Panem', 'Panem (United States)']
