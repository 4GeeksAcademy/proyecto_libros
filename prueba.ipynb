# %%
#prueba de repistorio

# %%
import pandas as pd

# %%
df = pd.read_csv('books_1.Best_Books_Ever.csv')
df
# Out:
#                                             bookId  \
# 0                         2767052-the-hunger-games
# 1      2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                       2657.To_Kill_a_Mockingbird
# 3                         1885.Pride_and_Prejudice
# 4                                   41865.Twilight
# ...                                            ...
# 52473                           11492014-fractured
# 52474                             11836711-anasazi
# 52475                              10815662-marked
# 52476                         11330278-wayward-son
# 52477                 10991547-daughter-of-helaman
#
#                                            title                 series  \
# 0                               The Hunger Games    The Hunger Games #1
# 1      Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                          To Kill a Mockingbird  To Kill a Mockingbird
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52478 entries, 0 to 52477
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   bookId            52478 non-null  object
#  1   title             52478 non-null  object
#  2   series            23470 non-null  object
#  3   author            52478 non-null  object
#  4   rating            52478 non-null  float64
#  5   description       51140 non-null  object
#  6   language          48672 non-null  object
#  7   isbn              52478 non-null  object
#  8   genres            52478 non-null  object
#  9   characters        52478 non-null  object
#  10  bookFormat        51005 non-null  object
#  11  edition           4955 non-null   object
#  12  pages             50131 non-null  object
#  13  publisher         48782 non-null  object
#  14  publishDate       51598 non-null  object
#  15  firstPublishDate  31152 non-null  object
# ...

# %%
import pandas as pd
from dateutil import parser

df = pd.read_csv('books_enriched_full.csv')  

def parse_date(date):
    try:
        return parser.parse(str(date)).date()
    except:
        return pd.NaT  

df['publishDate'] = df['publishDate'].apply(parse_date)
df['firstPublishDate'] = df['firstPublishDate'].apply(parse_date)

df['publishDate'] = pd.to_datetime(df['publishDate'])
df['firstPublishDate'] = pd.to_datetime(df['firstPublishDate'])

print(df[['publishDate', 'firstPublishDate']].head())
# Out:
# ---------------------------------------------------------------------------
# OutOfBoundsDatetime                       Traceback (most recent call last)
# Cell In[1], line 15
#      12 df['publishDate'] = df['publishDate'].apply(parse_date)
#      13 df['firstPublishDate'] = df['firstPublishDate'].apply(parse_date)
# ---> 15 df['publishDate'] = pd.to_datetime(df['publishDate'])
#      16 df['firstPublishDate'] = pd.to_datetime(df['firstPublishDate'])
#      18 print(df[['publishDate', 'firstPublishDate']].head())
#
# File c:\Users\elena\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1112, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1110         result = arg.map(cache_array)
#    1111     else:
# -> 1112         values = convert_listlike(arg._values, format)
#    1113         result = arg._constructor(values, index=arg.index, name=arg.name)
# ...

# %%
print(df_full.loc[11231])
